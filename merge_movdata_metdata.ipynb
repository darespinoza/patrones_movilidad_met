# %%
import pandas as pd
import pygrib
import numpy as np
from datetime import datetime, timedelta
from scipy.spatial import cKDTree
from scipy.interpolate import griddata
import warnings
warnings.filterwarnings('ignore')

class GRIBClimateExtractor:
    def __init__(self, grib_file):
        self.grib_file = grib_file
        self.grib_data = {}
        self.spatial_tree = None
        self.grid_coords = None
        self.time_index = {}
        
    def load_grib_data(self, variables=None):
        """Load GRIB data into memory with spatial indexing"""
        print("🔄 Loading GRIB data...")
        
        grbs = pygrib.open(self.grib_file)
        
        # First pass: catalog all available data
        available_vars = set()
        available_times = set()
        
        for grb in grbs:
            available_vars.add(grb.parameterName)
            available_times.add(grb.validDate)
        
        grbs.rewind()
        
        # Use specified variables or all available
        if variables is None:
            variables = list(available_vars)
        
        print(f"📊 Loading variables: {variables}")
        print(f"📅 Time range: {min(available_times)} to {max(available_times)}")
        
        # Second pass: load data
        for grb in grbs:
            if grb.parameterName in variables:
                var_name = grb.parameterName
                timestamp = grb.validDate
                level = grb.level
                
                # Create nested structure: variable -> time -> level
                if var_name not in self.grib_data:
                    self.grib_data[var_name] = {}
                if timestamp not in self.grib_data[var_name]:
                    self.grib_data[var_name][timestamp] = {}
                
                # Get coordinates and data
                data = grb.values
                lats, lons = grb.latlons()
                
                # Handle longitude format (convert to -180 to 180 if needed)
                if lons.max() > 180:
                    lons = np.where(lons > 180, lons - 360, lons)
                
                self.grib_data[var_name][timestamp][level] = {
                    'data': data,
                    'lats': lats,
                    'lons': lons,
                    'units': grb.parameterUnits
                }
                
                # Build spatial index from first variable/time (assuming same grid)
                if self.spatial_tree is None:
                    flat_lats = lats.flatten()
                    flat_lons = lons.flatten()
                    self.grid_coords = np.column_stack([flat_lats, flat_lons])
                    self.spatial_tree = cKDTree(self.grid_coords)
                    print(f"🗺️  Built spatial index with {len(self.grid_coords)} grid points")
        
        grbs.close()
        
        # Build time index for each variable
        for var_name in self.grib_data:
            self.time_index[var_name] = sorted(self.grib_data[var_name].keys())
        
        print(f"✅ Loaded {len(self.grib_data)} variables")
    
    def find_nearest_time(self, target_time, var_name, max_hours_diff=6):
        """Find nearest available time for a variable"""
        available_times = self.time_index[var_name]
        
        # Convert target time to datetime if string
        if isinstance(target_time, str):
            # Handle different timestamp formats
            if target_time.endswith('Z'):
                target_time = datetime.fromisoformat(target_time.replace('Z', '+00:00'))
            elif '+' in target_time or target_time.endswith('UTC'):
                target_time = datetime.fromisoformat(target_time.replace('UTC', '+00:00'))
            else:
                target_time = datetime.fromisoformat(target_time)
        
        # Make target_time timezone naive (remove timezone info to match GRIB times)
        if target_time.tzinfo is not None:
            target_time = target_time.replace(tzinfo=None)
        
        # Ensure GRIB times are also timezone naive
        naive_available_times = []
        for t in available_times:
            if hasattr(t, 'tzinfo') and t.tzinfo is not None:
                naive_available_times.append(t.replace(tzinfo=None))
            else:
                naive_available_times.append(t)
        
        # Find closest time
        time_diffs = [abs((t - target_time).total_seconds()) for t in naive_available_times]
        min_idx = np.argmin(time_diffs)
        closest_time = available_times[min_idx]  # Return original time object
        
        # Check if within acceptable range
        hours_diff = abs((naive_available_times[min_idx] - target_time).total_seconds()) / 3600
        if hours_diff > max_hours_diff:
            return None, hours_diff
        
        return closest_time, hours_diff
    
    def extract_point_data(self, lat, lon, timestamp, variables, interpolation='nearest'):
        """Extract climate data for a single point"""
        results = {}
        
        for var_name in variables:
            if var_name not in self.grib_data:
                results[var_name] = {'value': np.nan, 'units': '', 'time_diff_hours': np.nan}
                continue
            
            # Find nearest time
            nearest_time, time_diff = self.find_nearest_time(timestamp, var_name)
            if nearest_time is None:
                results[var_name] = {'value': np.nan, 'units': '', 'time_diff_hours': time_diff}
                continue
            
            # Get data for the nearest time (assume surface level for now)
            time_data = self.grib_data[var_name][nearest_time]
            level = list(time_data.keys())[0]  # Take first available level
            
            data_info = time_data[level]
            data = data_info['data']
            lats = data_info['lats']
            lons = data_info['lons']
            units = data_info['units']
            
            # Spatial interpolation
            if interpolation == 'nearest':
                # Find nearest grid point
                distances, indices = self.spatial_tree.query([lat, lon], k=1)
                grid_idx = np.unravel_index(indices, data.shape)
                value = data[grid_idx]
            
            elif interpolation == 'bilinear':
                # Bilinear interpolation
                flat_data = data.flatten()
                valid_mask = ~np.isnan(flat_data)
                
                if valid_mask.sum() < 4:  # Not enough points for interpolation
                    value = np.nan
                else:
                    try:
                        value = griddata(
                            self.grid_coords[valid_mask], 
                            flat_data[valid_mask], 
                            (lat, lon), 
                            method='linear'
                        )
                        if np.isnan(value):  # If linear fails, use nearest
                            value = griddata(
                                self.grid_coords[valid_mask], 
                                flat_data[valid_mask], 
                                (lat, lon), 
                                method='nearest'
                            )
                    except:
                        value = np.nan
            
            results[var_name] = {
                'value': float(value) if not np.isnan(value) else np.nan,
                'units': units,
                'time_diff_hours': time_diff
            }
        
        return results
    
    def process_csv_batch(self, csv_file, output_file, variables, 
                         batch_size=10000, interpolation='nearest'):
        """Process CSV file in batches"""
        
        print(f"🔄 Processing CSV file: {csv_file}")
        print(f"📦 Batch size: {batch_size}")
        print(f"🎯 Variables to extract: {variables}")
        
        # Read CSV info first
        total_rows = sum(1 for _ in open(csv_file)) - 1  # Subtract header
        print(f"📊 Total rows to process: {total_rows:,}")
        
        # Initialize output file
        first_batch = True
        processed_rows = 0
        
        # Process in chunks
        for chunk_num, df_chunk in enumerate(pd.read_csv(csv_file, chunksize=batch_size)):
            print(f"🔄 Processing batch {chunk_num + 1} ({len(df_chunk):,} rows)...")
            
            # Prepare results DataFrame
            results_list = []
            
            for idx, row in df_chunk.iterrows():
                # lat = row['latitude'] if 'Latitude' in row else row['lat']
                # lon = row['longitude'] if 'Longitude' in row else row['lon']
                # timestamp = row['timestamp'] if 'Datetime' in row else row['time']
                lat = row['Latitude']
                lon = row['Longitude']
                timestamp = row['Datetime']
                
                
                # Extract climate data
                climate_data = self.extract_point_data(lat, lon, timestamp, variables, interpolation)
                
                # Prepare result row
                result_row = {
                    'original_index': idx,
                    'latitude': lat,
                    'longitude': lon,
                    'timestamp': timestamp
                }
                
                # Add climate variables
                for var_name, var_data in climate_data.items():
                    result_row[f"{var_name}_value"] = var_data['value']
                    result_row[f"{var_name}_units"] = var_data['units']
                    result_row[f"{var_name}_time_diff_hours"] = var_data['time_diff_hours']
                
                results_list.append(result_row)
            
            # Convert to DataFrame and save
            results_df = pd.DataFrame(results_list)
            
            # Write to file (append after first batch)
            mode = 'w' if first_batch else 'a'
            header = first_batch
            results_df.to_csv(output_file, mode=mode, header=header, index=False)
            first_batch = False
            
            processed_rows += len(df_chunk)
            progress = (processed_rows / total_rows) * 100
            print(f"✅ Batch {chunk_num + 1} complete. Progress: {progress:.1f}%")
            
            # Memory cleanup
            del results_df, results_list
        
        print(f"🎉 Processing complete! Results saved to: {output_file}")
        return output_file

# Usage functions
def quick_grib_info(grib_file):
    """Quick overview of GRIB file contents"""
    grbs = pygrib.open(grib_file)
    
    variables = set()
    times = set()
    
    for grb in grbs:
        variables.add(grb.parameterName)
        times.add(grb.validDate)
    
    grbs.close()
    
    print("📊 GRIB File Overview:")
    print(f"Variables: {sorted(list(variables))}")
    print(f"Time range: {min(times)} to {max(times)}")
    print(f"Total times: {len(times)}")
    
    return sorted(list(variables)), sorted(list(times))

def process_climate_data(grib_file, csv_file, output_file, 
                        variables=None, batch_size=10000, interpolation='nearest'):
    """Main function to process climate data extraction"""
    
    # Initialize extractor
    extractor = GRIBClimateExtractor(grib_file)
    
    # Quick info if variables not specified
    if variables is None:
        available_vars, _ = quick_grib_info(grib_file)
        print(f"\n🔍 Available variables: {available_vars}")
        variables = available_vars[:3]  # Use first 3 variables by default
        print(f"🎯 Using variables: {variables}")
    
    # Load GRIB data
    extractor.load_grib_data(variables)
    
    # Process CSV
    result_file = extractor.process_csv_batch(
        csv_file, output_file, variables, batch_size, interpolation
    )
    
    return result_file

# %%
if __name__ == "__main__":
    # Configuration
    grib_file = "copernicus_era5land_data/azuay_era5land_abril2024.grib"
    csv_file = "raw_data/hash queryabril2024.csv"
    output_file = "transformed_data/hash queryabril2024_with-temp-precip.csv"
    
    # Variables you want to extract (None = all available)
    # variables_to_extract = None  # or ['Temperature', 'Precipitation', 'Wind speed']
    variables_to_extract = ['2 metre temperature', 'Total precipitation']
    
    try:
        # Process the data
        result_file = process_climate_data(
            grib_file=grib_file,
            csv_file=csv_file,
            output_file=output_file,
            variables=variables_to_extract,
            batch_size=5000,  # Adjust based on your memory
            interpolation='nearest'  # 'nearest' or 'bilinear'
        )
        
        print(f"\n🎉 Success! Climate data extracted to: {result_file}")
        
    except Exception as e:
        print(f"❌ Error: {e}")
        print("Make sure your file paths are correct and pygrib is installed.")
# Out:
# 🔄 Loading GRIB data...
# 📊 Loading variables: ['2 metre temperature', 'Total precipitation']
# 📅 Time range: 2024-03-31 00:00:00 to 2024-04-30 00:00:00
# 🗺️  Built spatial index with 169 grid points
# ✅ Loaded 2 variables
# 🔄 Processing CSV file: raw_data/hash queryabril2024.csv
# 📦 Batch size: 5000
# 🎯 Variables to extract: ['2 metre temperature', 'Total precipitation']
# 📊 Total rows to process: 5,616,509
# 🔄 Processing batch 1 (5,000 rows)...
# ✅ Batch 1 complete. Progress: 0.1%
# 🔄 Processing batch 2 (5,000 rows)...
# ✅ Batch 2 complete. Progress: 0.2%
# 🔄 Processing batch 3 (5,000 rows)...
# ✅ Batch 3 complete. Progress: 0.3%
# 🔄 Processing batch 4 (5,000 rows)...
# ✅ Batch 4 complete. Progress: 0.4%
# 🔄 Processing batch 5 (5,000 rows)...
# ✅ Batch 5 complete. Progress: 0.4%
# 🔄 Processing batch 6 (5,000 rows)...
# ✅ Batch 6 complete. Progress: 0.5%
# 🔄 Processing batch 7 (5,000 rows)...
# ✅ Batch 7 complete. Progress: 0.6%
# 🔄 Processing batch 8 (5,000 rows)...
# ✅ Batch 8 complete. Progress: 0.7%
# 🔄 Processing batch 9 (5,000 rows)...
# ✅ Batch 9 complete. Progress: 0.8%
# 🔄 Processing batch 10 (5,000 rows)...
# ✅ Batch 10 complete. Progress: 0.9%
# 🔄 Processing batch 11 (5,000 rows)...
# ✅ Batch 11 complete. Progress: 1.0%
# 🔄 Processing batch 12 (5,000 rows)...
# ✅ Batch 12 complete. Progress: 1.1%
# 🔄 Processing batch 13 (5,000 rows)...
# ✅ Batch 13 complete. Progress: 1.2%
# 🔄 Processing batch 14 (5,000 rows)...
# ✅ Batch 14 complete. Progress: 1.2%
# 🔄 Processing batch 15 (5,000 rows)...
# ✅ Batch 15 complete. Progress: 1.3%
# 🔄 Processing batch 16 (5,000 rows)...
# ✅ Batch 16 complete. Progress: 1.4%
# 🔄 Processing batch 17 (5,000 rows)...
# ✅ Batch 17 complete. Progress: 1.5%
# 🔄 Processing batch 18 (5,000 rows)...
# ✅ Batch 18 complete. Progress: 1.6%
# 🔄 Processing batch 19 (5,000 rows)...
# ✅ Batch 19 complete. Progress: 1.7%
# 🔄 Processing batch 20 (5,000 rows)...
# ✅ Batch 20 complete. Progress: 1.8%
# 🔄 Processing batch 21 (5,000 rows)...
# ✅ Batch 21 complete. Progress: 1.9%
# 🔄 Processing batch 22 (5,000 rows)...
# ✅ Batch 22 complete. Progress: 2.0%
# 🔄 Processing batch 23 (5,000 rows)...
# ✅ Batch 23 complete. Progress: 2.0%
# 🔄 Processing batch 24 (5,000 rows)...
# ✅ Batch 24 complete. Progress: 2.1%
# 🔄 Processing batch 25 (5,000 rows)...
# ✅ Batch 25 complete. Progress: 2.2%
# 🔄 Processing batch 26 (5,000 rows)...
# ✅ Batch 26 complete. Progress: 2.3%
# 🔄 Processing batch 27 (5,000 rows)...
# ✅ Batch 27 complete. Progress: 2.4%
# 🔄 Processing batch 28 (5,000 rows)...
# ✅ Batch 28 complete. Progress: 2.5%
# 🔄 Processing batch 29 (5,000 rows)...
# ✅ Batch 29 complete. Progress: 2.6%
# 🔄 Processing batch 30 (5,000 rows)...
# ✅ Batch 30 complete. Progress: 2.7%
# 🔄 Processing batch 31 (5,000 rows)...
# ✅ Batch 31 complete. Progress: 2.8%
# 🔄 Processing batch 32 (5,000 rows)...
# ✅ Batch 32 complete. Progress: 2.8%
# 🔄 Processing batch 33 (5,000 rows)...
# ✅ Batch 33 complete. Progress: 2.9%
# 🔄 Processing batch 34 (5,000 rows)...
# ✅ Batch 34 complete. Progress: 3.0%
# 🔄 Processing batch 35 (5,000 rows)...
# ✅ Batch 35 complete. Progress: 3.1%
# 🔄 Processing batch 36 (5,000 rows)...
# ✅ Batch 36 complete. Progress: 3.2%
# 🔄 Processing batch 37 (5,000 rows)...
# ✅ Batch 37 complete. Progress: 3.3%
# 🔄 Processing batch 38 (5,000 rows)...
# ✅ Batch 38 complete. Progress: 3.4%
# 🔄 Processing batch 39 (5,000 rows)...
# ✅ Batch 39 complete. Progress: 3.5%
# 🔄 Processing batch 40 (5,000 rows)...
# ✅ Batch 40 complete. Progress: 3.6%
# 🔄 Processing batch 41 (5,000 rows)...
# ✅ Batch 41 complete. Progress: 3.6%
# 🔄 Processing batch 42 (5,000 rows)...
# ✅ Batch 42 complete. Progress: 3.7%
# 🔄 Processing batch 43 (5,000 rows)...
# ✅ Batch 43 complete. Progress: 3.8%
# 🔄 Processing batch 44 (5,000 rows)...
# ✅ Batch 44 complete. Progress: 3.9%
# 🔄 Processing batch 45 (5,000 rows)...
# ✅ Batch 45 complete. Progress: 4.0%
# 🔄 Processing batch 46 (5,000 rows)...
# ✅ Batch 46 complete. Progress: 4.1%
# 🔄 Processing batch 47 (5,000 rows)...
# ✅ Batch 47 complete. Progress: 4.2%
# 🔄 Processing batch 48 (5,000 rows)...
# ✅ Batch 48 complete. Progress: 4.3%
# 🔄 Processing batch 49 (5,000 rows)...
# ✅ Batch 49 complete. Progress: 4.4%
# 🔄 Processing batch 50 (5,000 rows)...
# ✅ Batch 50 complete. Progress: 4.5%
# 🔄 Processing batch 51 (5,000 rows)...
# ✅ Batch 51 complete. Progress: 4.5%
# 🔄 Processing batch 52 (5,000 rows)...
# ✅ Batch 52 complete. Progress: 4.6%
# 🔄 Processing batch 53 (5,000 rows)...
# ✅ Batch 53 complete. Progress: 4.7%
# 🔄 Processing batch 54 (5,000 rows)...
# ✅ Batch 54 complete. Progress: 4.8%
# 🔄 Processing batch 55 (5,000 rows)...
# ✅ Batch 55 complete. Progress: 4.9%
# 🔄 Processing batch 56 (5,000 rows)...
# ✅ Batch 56 complete. Progress: 5.0%
# 🔄 Processing batch 57 (5,000 rows)...
# ✅ Batch 57 complete. Progress: 5.1%
# 🔄 Processing batch 58 (5,000 rows)...
# ✅ Batch 58 complete. Progress: 5.2%
# 🔄 Processing batch 59 (5,000 rows)...
# ✅ Batch 59 complete. Progress: 5.3%
# 🔄 Processing batch 60 (5,000 rows)...
# ✅ Batch 60 complete. Progress: 5.3%
# 🔄 Processing batch 61 (5,000 rows)...
# ✅ Batch 61 complete. Progress: 5.4%
# 🔄 Processing batch 62 (5,000 rows)...
# ✅ Batch 62 complete. Progress: 5.5%
# 🔄 Processing batch 63 (5,000 rows)...
# ✅ Batch 63 complete. Progress: 5.6%
# 🔄 Processing batch 64 (5,000 rows)...
# ✅ Batch 64 complete. Progress: 5.7%
# 🔄 Processing batch 65 (5,000 rows)...
# ✅ Batch 65 complete. Progress: 5.8%
# 🔄 Processing batch 66 (5,000 rows)...
# ✅ Batch 66 complete. Progress: 5.9%
# 🔄 Processing batch 67 (5,000 rows)...
# ✅ Batch 67 complete. Progress: 6.0%
# 🔄 Processing batch 68 (5,000 rows)...
# ✅ Batch 68 complete. Progress: 6.1%
# 🔄 Processing batch 69 (5,000 rows)...
# ✅ Batch 69 complete. Progress: 6.1%
# 🔄 Processing batch 70 (5,000 rows)...
# ✅ Batch 70 complete. Progress: 6.2%
# 🔄 Processing batch 71 (5,000 rows)...
# ✅ Batch 71 complete. Progress: 6.3%
# 🔄 Processing batch 72 (5,000 rows)...
# ✅ Batch 72 complete. Progress: 6.4%
# 🔄 Processing batch 73 (5,000 rows)...
# ✅ Batch 73 complete. Progress: 6.5%
# 🔄 Processing batch 74 (5,000 rows)...
# ✅ Batch 74 complete. Progress: 6.6%
# 🔄 Processing batch 75 (5,000 rows)...
# ✅ Batch 75 complete. Progress: 6.7%
# 🔄 Processing batch 76 (5,000 rows)...
# ✅ Batch 76 complete. Progress: 6.8%
# 🔄 Processing batch 77 (5,000 rows)...
# ✅ Batch 77 complete. Progress: 6.9%
# 🔄 Processing batch 78 (5,000 rows)...
# ✅ Batch 78 complete. Progress: 6.9%
# 🔄 Processing batch 79 (5,000 rows)...
# ✅ Batch 79 complete. Progress: 7.0%
# 🔄 Processing batch 80 (5,000 rows)...
# ✅ Batch 80 complete. Progress: 7.1%
# 🔄 Processing batch 81 (5,000 rows)...
# ✅ Batch 81 complete. Progress: 7.2%
# 🔄 Processing batch 82 (5,000 rows)...
# ✅ Batch 82 complete. Progress: 7.3%
# 🔄 Processing batch 83 (5,000 rows)...
# ✅ Batch 83 complete. Progress: 7.4%
# 🔄 Processing batch 84 (5,000 rows)...
# ✅ Batch 84 complete. Progress: 7.5%
# 🔄 Processing batch 85 (5,000 rows)...
# ✅ Batch 85 complete. Progress: 7.6%
# 🔄 Processing batch 86 (5,000 rows)...
# ✅ Batch 86 complete. Progress: 7.7%
# 🔄 Processing batch 87 (5,000 rows)...
# ✅ Batch 87 complete. Progress: 7.7%
# 🔄 Processing batch 88 (5,000 rows)...
# ✅ Batch 88 complete. Progress: 7.8%
# 🔄 Processing batch 89 (5,000 rows)...
# ✅ Batch 89 complete. Progress: 7.9%
# 🔄 Processing batch 90 (5,000 rows)...
# ✅ Batch 90 complete. Progress: 8.0%
# 🔄 Processing batch 91 (5,000 rows)...
# ✅ Batch 91 complete. Progress: 8.1%
# 🔄 Processing batch 92 (5,000 rows)...
# ✅ Batch 92 complete. Progress: 8.2%
# 🔄 Processing batch 93 (5,000 rows)...
# ✅ Batch 93 complete. Progress: 8.3%
# 🔄 Processing batch 94 (5,000 rows)...
# ✅ Batch 94 complete. Progress: 8.4%
# 🔄 Processing batch 95 (5,000 rows)...
# ✅ Batch 95 complete. Progress: 8.5%
# 🔄 Processing batch 96 (5,000 rows)...
# ✅ Batch 96 complete. Progress: 8.5%
# 🔄 Processing batch 97 (5,000 rows)...
# ✅ Batch 97 complete. Progress: 8.6%
# 🔄 Processing batch 98 (5,000 rows)...
# ✅ Batch 98 complete. Progress: 8.7%
# 🔄 Processing batch 99 (5,000 rows)...
# ✅ Batch 99 complete. Progress: 8.8%
# 🔄 Processing batch 100 (5,000 rows)...
# ✅ Batch 100 complete. Progress: 8.9%
# 🔄 Processing batch 101 (5,000 rows)...
# ✅ Batch 101 complete. Progress: 9.0%
# 🔄 Processing batch 102 (5,000 rows)...
# ✅ Batch 102 complete. Progress: 9.1%
# 🔄 Processing batch 103 (5,000 rows)...
# ✅ Batch 103 complete. Progress: 9.2%
# 🔄 Processing batch 104 (5,000 rows)...
# ✅ Batch 104 complete. Progress: 9.3%
# 🔄 Processing batch 105 (5,000 rows)...
# ✅ Batch 105 complete. Progress: 9.3%
# 🔄 Processing batch 106 (5,000 rows)...
# ✅ Batch 106 complete. Progress: 9.4%
# 🔄 Processing batch 107 (5,000 rows)...
# ✅ Batch 107 complete. Progress: 9.5%
# 🔄 Processing batch 108 (5,000 rows)...
# ✅ Batch 108 complete. Progress: 9.6%
# 🔄 Processing batch 109 (5,000 rows)...
# ✅ Batch 109 complete. Progress: 9.7%
# 🔄 Processing batch 110 (5,000 rows)...
# ✅ Batch 110 complete. Progress: 9.8%
# 🔄 Processing batch 111 (5,000 rows)...
# ✅ Batch 111 complete. Progress: 9.9%
# 🔄 Processing batch 112 (5,000 rows)...
# ✅ Batch 112 complete. Progress: 10.0%
# 🔄 Processing batch 113 (5,000 rows)...
# ✅ Batch 113 complete. Progress: 10.1%
# 🔄 Processing batch 114 (5,000 rows)...
# ✅ Batch 114 complete. Progress: 10.1%
# 🔄 Processing batch 115 (5,000 rows)...
# ✅ Batch 115 complete. Progress: 10.2%
# 🔄 Processing batch 116 (5,000 rows)...
# ✅ Batch 116 complete. Progress: 10.3%
# 🔄 Processing batch 117 (5,000 rows)...
# ✅ Batch 117 complete. Progress: 10.4%
# 🔄 Processing batch 118 (5,000 rows)...
# ✅ Batch 118 complete. Progress: 10.5%
# 🔄 Processing batch 119 (5,000 rows)...
# ✅ Batch 119 complete. Progress: 10.6%
# 🔄 Processing batch 120 (5,000 rows)...
# ✅ Batch 120 complete. Progress: 10.7%
# 🔄 Processing batch 121 (5,000 rows)...
# ✅ Batch 121 complete. Progress: 10.8%
# 🔄 Processing batch 122 (5,000 rows)...
# ✅ Batch 122 complete. Progress: 10.9%
# 🔄 Processing batch 123 (5,000 rows)...
# ✅ Batch 123 complete. Progress: 10.9%
# 🔄 Processing batch 124 (5,000 rows)...
# ✅ Batch 124 complete. Progress: 11.0%
# 🔄 Processing batch 125 (5,000 rows)...
# ✅ Batch 125 complete. Progress: 11.1%
# 🔄 Processing batch 126 (5,000 rows)...
# ✅ Batch 126 complete. Progress: 11.2%
# 🔄 Processing batch 127 (5,000 rows)...
# ✅ Batch 127 complete. Progress: 11.3%
# 🔄 Processing batch 128 (5,000 rows)...
# ✅ Batch 128 complete. Progress: 11.4%
# 🔄 Processing batch 129 (5,000 rows)...
# ✅ Batch 129 complete. Progress: 11.5%
# 🔄 Processing batch 130 (5,000 rows)...
# ✅ Batch 130 complete. Progress: 11.6%
# 🔄 Processing batch 131 (5,000 rows)...
# ✅ Batch 131 complete. Progress: 11.7%
# 🔄 Processing batch 132 (5,000 rows)...
# ✅ Batch 132 complete. Progress: 11.8%
# 🔄 Processing batch 133 (5,000 rows)...
# ✅ Batch 133 complete. Progress: 11.8%
# 🔄 Processing batch 134 (5,000 rows)...
# ✅ Batch 134 complete. Progress: 11.9%
# 🔄 Processing batch 135 (5,000 rows)...
# ✅ Batch 135 complete. Progress: 12.0%
# 🔄 Processing batch 136 (5,000 rows)...
# ✅ Batch 136 complete. Progress: 12.1%
# 🔄 Processing batch 137 (5,000 rows)...
# ✅ Batch 137 complete. Progress: 12.2%
# 🔄 Processing batch 138 (5,000 rows)...
# ✅ Batch 138 complete. Progress: 12.3%
# 🔄 Processing batch 139 (5,000 rows)...
# ✅ Batch 139 complete. Progress: 12.4%
# 🔄 Processing batch 140 (5,000 rows)...
# ✅ Batch 140 complete. Progress: 12.5%
# 🔄 Processing batch 141 (5,000 rows)...
# ✅ Batch 141 complete. Progress: 12.6%
# 🔄 Processing batch 142 (5,000 rows)...
# ✅ Batch 142 complete. Progress: 12.6%
# 🔄 Processing batch 143 (5,000 rows)...
# ✅ Batch 143 complete. Progress: 12.7%
# 🔄 Processing batch 144 (5,000 rows)...
# ✅ Batch 144 complete. Progress: 12.8%
# 🔄 Processing batch 145 (5,000 rows)...
# ✅ Batch 145 complete. Progress: 12.9%
# 🔄 Processing batch 146 (5,000 rows)...
# ✅ Batch 146 complete. Progress: 13.0%
# 🔄 Processing batch 147 (5,000 rows)...
# ✅ Batch 147 complete. Progress: 13.1%
# 🔄 Processing batch 148 (5,000 rows)...
# ✅ Batch 148 complete. Progress: 13.2%
# 🔄 Processing batch 149 (5,000 rows)...
# ✅ Batch 149 complete. Progress: 13.3%
# 🔄 Processing batch 150 (5,000 rows)...
# ✅ Batch 150 complete. Progress: 13.4%
# 🔄 Processing batch 151 (5,000 rows)...
# ✅ Batch 151 complete. Progress: 13.4%
# 🔄 Processing batch 152 (5,000 rows)...
# ✅ Batch 152 complete. Progress: 13.5%
# 🔄 Processing batch 153 (5,000 rows)...
# ✅ Batch 153 complete. Progress: 13.6%
# 🔄 Processing batch 154 (5,000 rows)...
# ✅ Batch 154 complete. Progress: 13.7%
# 🔄 Processing batch 155 (5,000 rows)...
# ✅ Batch 155 complete. Progress: 13.8%
# 🔄 Processing batch 156 (5,000 rows)...
# ✅ Batch 156 complete. Progress: 13.9%
# 🔄 Processing batch 157 (5,000 rows)...
# ✅ Batch 157 complete. Progress: 14.0%
# 🔄 Processing batch 158 (5,000 rows)...
# ✅ Batch 158 complete. Progress: 14.1%
# 🔄 Processing batch 159 (5,000 rows)...
# ✅ Batch 159 complete. Progress: 14.2%
# 🔄 Processing batch 160 (5,000 rows)...
# ✅ Batch 160 complete. Progress: 14.2%
# 🔄 Processing batch 161 (5,000 rows)...
# ✅ Batch 161 complete. Progress: 14.3%
# 🔄 Processing batch 162 (5,000 rows)...
# ✅ Batch 162 complete. Progress: 14.4%
# 🔄 Processing batch 163 (5,000 rows)...
# ✅ Batch 163 complete. Progress: 14.5%
# 🔄 Processing batch 164 (5,000 rows)...
# ✅ Batch 164 complete. Progress: 14.6%
# 🔄 Processing batch 165 (5,000 rows)...
# ✅ Batch 165 complete. Progress: 14.7%
# 🔄 Processing batch 166 (5,000 rows)...
# ✅ Batch 166 complete. Progress: 14.8%
# 🔄 Processing batch 167 (5,000 rows)...
# ✅ Batch 167 complete. Progress: 14.9%
# 🔄 Processing batch 168 (5,000 rows)...
# ✅ Batch 168 complete. Progress: 15.0%
# 🔄 Processing batch 169 (5,000 rows)...
# ✅ Batch 169 complete. Progress: 15.0%
# 🔄 Processing batch 170 (5,000 rows)...
# ✅ Batch 170 complete. Progress: 15.1%
# 🔄 Processing batch 171 (5,000 rows)...
# ✅ Batch 171 complete. Progress: 15.2%
# 🔄 Processing batch 172 (5,000 rows)...
# ✅ Batch 172 complete. Progress: 15.3%
# 🔄 Processing batch 173 (5,000 rows)...
# ✅ Batch 173 complete. Progress: 15.4%
# 🔄 Processing batch 174 (5,000 rows)...
# ✅ Batch 174 complete. Progress: 15.5%
# 🔄 Processing batch 175 (5,000 rows)...
# ✅ Batch 175 complete. Progress: 15.6%
# 🔄 Processing batch 176 (5,000 rows)...
# ✅ Batch 176 complete. Progress: 15.7%
# 🔄 Processing batch 177 (5,000 rows)...
# ✅ Batch 177 complete. Progress: 15.8%
# 🔄 Processing batch 178 (5,000 rows)...
# ✅ Batch 178 complete. Progress: 15.8%
# 🔄 Processing batch 179 (5,000 rows)...
# ✅ Batch 179 complete. Progress: 15.9%
# 🔄 Processing batch 180 (5,000 rows)...
# ✅ Batch 180 complete. Progress: 16.0%
# 🔄 Processing batch 181 (5,000 rows)...
# ✅ Batch 181 complete. Progress: 16.1%
# 🔄 Processing batch 182 (5,000 rows)...
# ✅ Batch 182 complete. Progress: 16.2%
# 🔄 Processing batch 183 (5,000 rows)...
# ✅ Batch 183 complete. Progress: 16.3%
# 🔄 Processing batch 184 (5,000 rows)...
# ✅ Batch 184 complete. Progress: 16.4%
# 🔄 Processing batch 185 (5,000 rows)...
# ✅ Batch 185 complete. Progress: 16.5%
# 🔄 Processing batch 186 (5,000 rows)...
# ✅ Batch 186 complete. Progress: 16.6%
# 🔄 Processing batch 187 (5,000 rows)...
# ✅ Batch 187 complete. Progress: 16.6%
# 🔄 Processing batch 188 (5,000 rows)...
# ✅ Batch 188 complete. Progress: 16.7%
# 🔄 Processing batch 189 (5,000 rows)...
# ✅ Batch 189 complete. Progress: 16.8%
# 🔄 Processing batch 190 (5,000 rows)...
# ✅ Batch 190 complete. Progress: 16.9%
# 🔄 Processing batch 191 (5,000 rows)...
# ✅ Batch 191 complete. Progress: 17.0%
# 🔄 Processing batch 192 (5,000 rows)...
# ✅ Batch 192 complete. Progress: 17.1%
# 🔄 Processing batch 193 (5,000 rows)...
# ✅ Batch 193 complete. Progress: 17.2%
# 🔄 Processing batch 194 (5,000 rows)...
# ✅ Batch 194 complete. Progress: 17.3%
# 🔄 Processing batch 195 (5,000 rows)...
# ✅ Batch 195 complete. Progress: 17.4%
# 🔄 Processing batch 196 (5,000 rows)...
# ✅ Batch 196 complete. Progress: 17.4%
# 🔄 Processing batch 197 (5,000 rows)...
# ✅ Batch 197 complete. Progress: 17.5%
# 🔄 Processing batch 198 (5,000 rows)...
# ✅ Batch 198 complete. Progress: 17.6%
# 🔄 Processing batch 199 (5,000 rows)...
# ✅ Batch 199 complete. Progress: 17.7%
# 🔄 Processing batch 200 (5,000 rows)...
# ✅ Batch 200 complete. Progress: 17.8%
# 🔄 Processing batch 201 (5,000 rows)...
# ✅ Batch 201 complete. Progress: 17.9%
# 🔄 Processing batch 202 (5,000 rows)...
# ✅ Batch 202 complete. Progress: 18.0%
# 🔄 Processing batch 203 (5,000 rows)...
# ✅ Batch 203 complete. Progress: 18.1%
# 🔄 Processing batch 204 (5,000 rows)...
# ✅ Batch 204 complete. Progress: 18.2%
# 🔄 Processing batch 205 (5,000 rows)...
# ✅ Batch 205 complete. Progress: 18.2%
# 🔄 Processing batch 206 (5,000 rows)...
# ✅ Batch 206 complete. Progress: 18.3%
# 🔄 Processing batch 207 (5,000 rows)...
# ✅ Batch 207 complete. Progress: 18.4%
# 🔄 Processing batch 208 (5,000 rows)...
# ✅ Batch 208 complete. Progress: 18.5%
# 🔄 Processing batch 209 (5,000 rows)...
# ✅ Batch 209 complete. Progress: 18.6%
# 🔄 Processing batch 210 (5,000 rows)...
# ✅ Batch 210 complete. Progress: 18.7%
# 🔄 Processing batch 211 (5,000 rows)...
# ✅ Batch 211 complete. Progress: 18.8%
# 🔄 Processing batch 212 (5,000 rows)...
# ✅ Batch 212 complete. Progress: 18.9%
# 🔄 Processing batch 213 (5,000 rows)...
# ✅ Batch 213 complete. Progress: 19.0%
# 🔄 Processing batch 214 (5,000 rows)...
# ✅ Batch 214 complete. Progress: 19.1%
# 🔄 Processing batch 215 (5,000 rows)...
# ✅ Batch 215 complete. Progress: 19.1%
# 🔄 Processing batch 216 (5,000 rows)...
# ✅ Batch 216 complete. Progress: 19.2%
# 🔄 Processing batch 217 (5,000 rows)...
# ✅ Batch 217 complete. Progress: 19.3%
# 🔄 Processing batch 218 (5,000 rows)...
# ✅ Batch 218 complete. Progress: 19.4%
# 🔄 Processing batch 219 (5,000 rows)...
# ✅ Batch 219 complete. Progress: 19.5%
# 🔄 Processing batch 220 (5,000 rows)...
# ✅ Batch 220 complete. Progress: 19.6%
# 🔄 Processing batch 221 (5,000 rows)...
# ✅ Batch 221 complete. Progress: 19.7%
# 🔄 Processing batch 222 (5,000 rows)...
# ✅ Batch 222 complete. Progress: 19.8%
# 🔄 Processing batch 223 (5,000 rows)...
# ✅ Batch 223 complete. Progress: 19.9%
# 🔄 Processing batch 224 (5,000 rows)...
# ✅ Batch 224 complete. Progress: 19.9%
# 🔄 Processing batch 225 (5,000 rows)...
# ✅ Batch 225 complete. Progress: 20.0%
# 🔄 Processing batch 226 (5,000 rows)...
# ✅ Batch 226 complete. Progress: 20.1%
# 🔄 Processing batch 227 (5,000 rows)...
# ✅ Batch 227 complete. Progress: 20.2%
# 🔄 Processing batch 228 (5,000 rows)...
# ✅ Batch 228 complete. Progress: 20.3%
# 🔄 Processing batch 229 (5,000 rows)...
# ✅ Batch 229 complete. Progress: 20.4%
# 🔄 Processing batch 230 (5,000 rows)...
# ✅ Batch 230 complete. Progress: 20.5%
# 🔄 Processing batch 231 (5,000 rows)...
# ✅ Batch 231 complete. Progress: 20.6%
# 🔄 Processing batch 232 (5,000 rows)...
# ✅ Batch 232 complete. Progress: 20.7%
# 🔄 Processing batch 233 (5,000 rows)...
# ✅ Batch 233 complete. Progress: 20.7%
# 🔄 Processing batch 234 (5,000 rows)...
# ✅ Batch 234 complete. Progress: 20.8%
# 🔄 Processing batch 235 (5,000 rows)...
# ✅ Batch 235 complete. Progress: 20.9%
# 🔄 Processing batch 236 (5,000 rows)...
# ✅ Batch 236 complete. Progress: 21.0%
# 🔄 Processing batch 237 (5,000 rows)...
# ✅ Batch 237 complete. Progress: 21.1%
# 🔄 Processing batch 238 (5,000 rows)...
# ✅ Batch 238 complete. Progress: 21.2%
# 🔄 Processing batch 239 (5,000 rows)...
# ✅ Batch 239 complete. Progress: 21.3%
# 🔄 Processing batch 240 (5,000 rows)...
# ✅ Batch 240 complete. Progress: 21.4%
# 🔄 Processing batch 241 (5,000 rows)...
# ✅ Batch 241 complete. Progress: 21.5%
# 🔄 Processing batch 242 (5,000 rows)...
# ✅ Batch 242 complete. Progress: 21.5%
# 🔄 Processing batch 243 (5,000 rows)...
# ✅ Batch 243 complete. Progress: 21.6%
# 🔄 Processing batch 244 (5,000 rows)...
# ✅ Batch 244 complete. Progress: 21.7%
# 🔄 Processing batch 245 (5,000 rows)...
# ✅ Batch 245 complete. Progress: 21.8%
# 🔄 Processing batch 246 (5,000 rows)...
# ✅ Batch 246 complete. Progress: 21.9%
# 🔄 Processing batch 247 (5,000 rows)...
# ✅ Batch 247 complete. Progress: 22.0%
# 🔄 Processing batch 248 (5,000 rows)...
# ✅ Batch 248 complete. Progress: 22.1%
# 🔄 Processing batch 249 (5,000 rows)...
# ✅ Batch 249 complete. Progress: 22.2%
# 🔄 Processing batch 250 (5,000 rows)...
# ✅ Batch 250 complete. Progress: 22.3%
# 🔄 Processing batch 251 (5,000 rows)...
# ✅ Batch 251 complete. Progress: 22.3%
# 🔄 Processing batch 252 (5,000 rows)...
# ✅ Batch 252 complete. Progress: 22.4%
# 🔄 Processing batch 253 (5,000 rows)...
# ✅ Batch 253 complete. Progress: 22.5%
# 🔄 Processing batch 254 (5,000 rows)...
# ✅ Batch 254 complete. Progress: 22.6%
# 🔄 Processing batch 255 (5,000 rows)...
# ✅ Batch 255 complete. Progress: 22.7%
# 🔄 Processing batch 256 (5,000 rows)...
# ✅ Batch 256 complete. Progress: 22.8%
# 🔄 Processing batch 257 (5,000 rows)...
# ✅ Batch 257 complete. Progress: 22.9%
# 🔄 Processing batch 258 (5,000 rows)...
# ✅ Batch 258 complete. Progress: 23.0%
# 🔄 Processing batch 259 (5,000 rows)...
# ✅ Batch 259 complete. Progress: 23.1%
# 🔄 Processing batch 260 (5,000 rows)...
# ✅ Batch 260 complete. Progress: 23.1%
# 🔄 Processing batch 261 (5,000 rows)...
# ✅ Batch 261 complete. Progress: 23.2%
# 🔄 Processing batch 262 (5,000 rows)...
# ✅ Batch 262 complete. Progress: 23.3%
# 🔄 Processing batch 263 (5,000 rows)...
# ✅ Batch 263 complete. Progress: 23.4%
# 🔄 Processing batch 264 (5,000 rows)...
# ✅ Batch 264 complete. Progress: 23.5%
# 🔄 Processing batch 265 (5,000 rows)...
# ✅ Batch 265 complete. Progress: 23.6%
# 🔄 Processing batch 266 (5,000 rows)...
# ✅ Batch 266 complete. Progress: 23.7%
# 🔄 Processing batch 267 (5,000 rows)...
# ✅ Batch 267 complete. Progress: 23.8%
# 🔄 Processing batch 268 (5,000 rows)...
# ✅ Batch 268 complete. Progress: 23.9%
# 🔄 Processing batch 269 (5,000 rows)...
# ✅ Batch 269 complete. Progress: 23.9%
# 🔄 Processing batch 270 (5,000 rows)...
# ✅ Batch 270 complete. Progress: 24.0%
# 🔄 Processing batch 271 (5,000 rows)...
# ✅ Batch 271 complete. Progress: 24.1%
# 🔄 Processing batch 272 (5,000 rows)...
# ✅ Batch 272 complete. Progress: 24.2%
# 🔄 Processing batch 273 (5,000 rows)...
# ✅ Batch 273 complete. Progress: 24.3%
# 🔄 Processing batch 274 (5,000 rows)...
# ✅ Batch 274 complete. Progress: 24.4%
# 🔄 Processing batch 275 (5,000 rows)...
# ✅ Batch 275 complete. Progress: 24.5%
# 🔄 Processing batch 276 (5,000 rows)...
# ✅ Batch 276 complete. Progress: 24.6%
# 🔄 Processing batch 277 (5,000 rows)...
# ✅ Batch 277 complete. Progress: 24.7%
# 🔄 Processing batch 278 (5,000 rows)...
# ✅ Batch 278 complete. Progress: 24.7%
# 🔄 Processing batch 279 (5,000 rows)...
# ✅ Batch 279 complete. Progress: 24.8%
# 🔄 Processing batch 280 (5,000 rows)...
# ✅ Batch 280 complete. Progress: 24.9%
# 🔄 Processing batch 281 (5,000 rows)...
# ✅ Batch 281 complete. Progress: 25.0%
# 🔄 Processing batch 282 (5,000 rows)...
# ✅ Batch 282 complete. Progress: 25.1%
# 🔄 Processing batch 283 (5,000 rows)...
# ✅ Batch 283 complete. Progress: 25.2%
# 🔄 Processing batch 284 (5,000 rows)...
# ✅ Batch 284 complete. Progress: 25.3%
# 🔄 Processing batch 285 (5,000 rows)...
# ✅ Batch 285 complete. Progress: 25.4%
# 🔄 Processing batch 286 (5,000 rows)...
# ✅ Batch 286 complete. Progress: 25.5%
# 🔄 Processing batch 287 (5,000 rows)...
# ✅ Batch 287 complete. Progress: 25.5%
# 🔄 Processing batch 288 (5,000 rows)...
# ✅ Batch 288 complete. Progress: 25.6%
# 🔄 Processing batch 289 (5,000 rows)...
# ✅ Batch 289 complete. Progress: 25.7%
# 🔄 Processing batch 290 (5,000 rows)...
# ✅ Batch 290 complete. Progress: 25.8%
# 🔄 Processing batch 291 (5,000 rows)...
# ✅ Batch 291 complete. Progress: 25.9%
# 🔄 Processing batch 292 (5,000 rows)...
# ✅ Batch 292 complete. Progress: 26.0%
# 🔄 Processing batch 293 (5,000 rows)...
# ✅ Batch 293 complete. Progress: 26.1%
# 🔄 Processing batch 294 (5,000 rows)...
# ✅ Batch 294 complete. Progress: 26.2%
# 🔄 Processing batch 295 (5,000 rows)...
# ✅ Batch 295 complete. Progress: 26.3%
# 🔄 Processing batch 296 (5,000 rows)...
# ✅ Batch 296 complete. Progress: 26.4%
# 🔄 Processing batch 297 (5,000 rows)...
# ✅ Batch 297 complete. Progress: 26.4%
# 🔄 Processing batch 298 (5,000 rows)...
# ✅ Batch 298 complete. Progress: 26.5%
# 🔄 Processing batch 299 (5,000 rows)...
# ✅ Batch 299 complete. Progress: 26.6%
# 🔄 Processing batch 300 (5,000 rows)...
# ✅ Batch 300 complete. Progress: 26.7%
# 🔄 Processing batch 301 (5,000 rows)...
# ✅ Batch 301 complete. Progress: 26.8%
# 🔄 Processing batch 302 (5,000 rows)...
# ✅ Batch 302 complete. Progress: 26.9%
# 🔄 Processing batch 303 (5,000 rows)...
# ✅ Batch 303 complete. Progress: 27.0%
# 🔄 Processing batch 304 (5,000 rows)...
# ✅ Batch 304 complete. Progress: 27.1%
# 🔄 Processing batch 305 (5,000 rows)...
# ✅ Batch 305 complete. Progress: 27.2%
# 🔄 Processing batch 306 (5,000 rows)...
# ✅ Batch 306 complete. Progress: 27.2%
# 🔄 Processing batch 307 (5,000 rows)...
# ✅ Batch 307 complete. Progress: 27.3%
# 🔄 Processing batch 308 (5,000 rows)...
# ✅ Batch 308 complete. Progress: 27.4%
# 🔄 Processing batch 309 (5,000 rows)...
# ✅ Batch 309 complete. Progress: 27.5%
# 🔄 Processing batch 310 (5,000 rows)...
# ✅ Batch 310 complete. Progress: 27.6%
# 🔄 Processing batch 311 (5,000 rows)...
# ✅ Batch 311 complete. Progress: 27.7%
# 🔄 Processing batch 312 (5,000 rows)...
# ✅ Batch 312 complete. Progress: 27.8%
# 🔄 Processing batch 313 (5,000 rows)...
# ✅ Batch 313 complete. Progress: 27.9%
# 🔄 Processing batch 314 (5,000 rows)...
# ✅ Batch 314 complete. Progress: 28.0%
# 🔄 Processing batch 315 (5,000 rows)...
# ✅ Batch 315 complete. Progress: 28.0%
# 🔄 Processing batch 316 (5,000 rows)...
# ✅ Batch 316 complete. Progress: 28.1%
# 🔄 Processing batch 317 (5,000 rows)...
# ✅ Batch 317 complete. Progress: 28.2%
# 🔄 Processing batch 318 (5,000 rows)...
# ✅ Batch 318 complete. Progress: 28.3%
# 🔄 Processing batch 319 (5,000 rows)...
# ✅ Batch 319 complete. Progress: 28.4%
# 🔄 Processing batch 320 (5,000 rows)...
# ✅ Batch 320 complete. Progress: 28.5%
# 🔄 Processing batch 321 (5,000 rows)...
# ✅ Batch 321 complete. Progress: 28.6%
# 🔄 Processing batch 322 (5,000 rows)...
# ✅ Batch 322 complete. Progress: 28.7%
# 🔄 Processing batch 323 (5,000 rows)...
# ✅ Batch 323 complete. Progress: 28.8%
# 🔄 Processing batch 324 (5,000 rows)...
# ✅ Batch 324 complete. Progress: 28.8%
# 🔄 Processing batch 325 (5,000 rows)...
# ✅ Batch 325 complete. Progress: 28.9%
# 🔄 Processing batch 326 (5,000 rows)...
# ✅ Batch 326 complete. Progress: 29.0%
# 🔄 Processing batch 327 (5,000 rows)...
# ✅ Batch 327 complete. Progress: 29.1%
# 🔄 Processing batch 328 (5,000 rows)...
# ✅ Batch 328 complete. Progress: 29.2%
# 🔄 Processing batch 329 (5,000 rows)...
# ✅ Batch 329 complete. Progress: 29.3%
# 🔄 Processing batch 330 (5,000 rows)...
# ✅ Batch 330 complete. Progress: 29.4%
# 🔄 Processing batch 331 (5,000 rows)...
# ✅ Batch 331 complete. Progress: 29.5%
# 🔄 Processing batch 332 (5,000 rows)...
# ✅ Batch 332 complete. Progress: 29.6%
# 🔄 Processing batch 333 (5,000 rows)...
# ✅ Batch 333 complete. Progress: 29.6%
# 🔄 Processing batch 334 (5,000 rows)...
# ✅ Batch 334 complete. Progress: 29.7%
# 🔄 Processing batch 335 (5,000 rows)...
# ✅ Batch 335 complete. Progress: 29.8%
# 🔄 Processing batch 336 (5,000 rows)...
# ✅ Batch 336 complete. Progress: 29.9%
# 🔄 Processing batch 337 (5,000 rows)...
# ✅ Batch 337 complete. Progress: 30.0%
# 🔄 Processing batch 338 (5,000 rows)...
# ✅ Batch 338 complete. Progress: 30.1%
# 🔄 Processing batch 339 (5,000 rows)...
# ✅ Batch 339 complete. Progress: 30.2%
# 🔄 Processing batch 340 (5,000 rows)...
# ✅ Batch 340 complete. Progress: 30.3%
# 🔄 Processing batch 341 (5,000 rows)...
# ✅ Batch 341 complete. Progress: 30.4%
# 🔄 Processing batch 342 (5,000 rows)...
# ✅ Batch 342 complete. Progress: 30.4%
# 🔄 Processing batch 343 (5,000 rows)...
# ✅ Batch 343 complete. Progress: 30.5%
# 🔄 Processing batch 344 (5,000 rows)...
# ✅ Batch 344 complete. Progress: 30.6%
# 🔄 Processing batch 345 (5,000 rows)...
# ✅ Batch 345 complete. Progress: 30.7%
# 🔄 Processing batch 346 (5,000 rows)...
# ✅ Batch 346 complete. Progress: 30.8%
# 🔄 Processing batch 347 (5,000 rows)...
# ✅ Batch 347 complete. Progress: 30.9%
# 🔄 Processing batch 348 (5,000 rows)...
# ✅ Batch 348 complete. Progress: 31.0%
# 🔄 Processing batch 349 (5,000 rows)...
# ✅ Batch 349 complete. Progress: 31.1%
# 🔄 Processing batch 350 (5,000 rows)...
# ✅ Batch 350 complete. Progress: 31.2%
# 🔄 Processing batch 351 (5,000 rows)...
# ✅ Batch 351 complete. Progress: 31.2%
# 🔄 Processing batch 352 (5,000 rows)...
# ✅ Batch 352 complete. Progress: 31.3%
# 🔄 Processing batch 353 (5,000 rows)...
# ✅ Batch 353 complete. Progress: 31.4%
# 🔄 Processing batch 354 (5,000 rows)...
# ✅ Batch 354 complete. Progress: 31.5%
# 🔄 Processing batch 355 (5,000 rows)...
# ✅ Batch 355 complete. Progress: 31.6%
# 🔄 Processing batch 356 (5,000 rows)...
# ✅ Batch 356 complete. Progress: 31.7%
# 🔄 Processing batch 357 (5,000 rows)...
# ✅ Batch 357 complete. Progress: 31.8%
# 🔄 Processing batch 358 (5,000 rows)...
# ✅ Batch 358 complete. Progress: 31.9%
# 🔄 Processing batch 359 (5,000 rows)...
# ✅ Batch 359 complete. Progress: 32.0%
# 🔄 Processing batch 360 (5,000 rows)...
# ✅ Batch 360 complete. Progress: 32.0%
# 🔄 Processing batch 361 (5,000 rows)...
# ✅ Batch 361 complete. Progress: 32.1%
# 🔄 Processing batch 362 (5,000 rows)...
# ✅ Batch 362 complete. Progress: 32.2%
# 🔄 Processing batch 363 (5,000 rows)...
# ✅ Batch 363 complete. Progress: 32.3%
# 🔄 Processing batch 364 (5,000 rows)...
# ✅ Batch 364 complete. Progress: 32.4%
# 🔄 Processing batch 365 (5,000 rows)...
# ✅ Batch 365 complete. Progress: 32.5%
# 🔄 Processing batch 366 (5,000 rows)...
# ✅ Batch 366 complete. Progress: 32.6%
# 🔄 Processing batch 367 (5,000 rows)...
# ✅ Batch 367 complete. Progress: 32.7%
# 🔄 Processing batch 368 (5,000 rows)...
# ✅ Batch 368 complete. Progress: 32.8%
# 🔄 Processing batch 369 (5,000 rows)...
# ✅ Batch 369 complete. Progress: 32.8%
# 🔄 Processing batch 370 (5,000 rows)...
# ✅ Batch 370 complete. Progress: 32.9%
# 🔄 Processing batch 371 (5,000 rows)...
# ✅ Batch 371 complete. Progress: 33.0%
# 🔄 Processing batch 372 (5,000 rows)...
# ✅ Batch 372 complete. Progress: 33.1%
# 🔄 Processing batch 373 (5,000 rows)...
# ✅ Batch 373 complete. Progress: 33.2%
# 🔄 Processing batch 374 (5,000 rows)...
# ✅ Batch 374 complete. Progress: 33.3%
# 🔄 Processing batch 375 (5,000 rows)...
# ✅ Batch 375 complete. Progress: 33.4%
# 🔄 Processing batch 376 (5,000 rows)...
# ✅ Batch 376 complete. Progress: 33.5%
# 🔄 Processing batch 377 (5,000 rows)...
# ✅ Batch 377 complete. Progress: 33.6%
# 🔄 Processing batch 378 (5,000 rows)...
# ✅ Batch 378 complete. Progress: 33.7%
# 🔄 Processing batch 379 (5,000 rows)...
# ✅ Batch 379 complete. Progress: 33.7%
# 🔄 Processing batch 380 (5,000 rows)...
# ✅ Batch 380 complete. Progress: 33.8%
# 🔄 Processing batch 381 (5,000 rows)...
# ✅ Batch 381 complete. Progress: 33.9%
# 🔄 Processing batch 382 (5,000 rows)...
# ✅ Batch 382 complete. Progress: 34.0%
# 🔄 Processing batch 383 (5,000 rows)...
# ✅ Batch 383 complete. Progress: 34.1%
# 🔄 Processing batch 384 (5,000 rows)...
# ✅ Batch 384 complete. Progress: 34.2%
# 🔄 Processing batch 385 (5,000 rows)...
# ✅ Batch 385 complete. Progress: 34.3%
# 🔄 Processing batch 386 (5,000 rows)...
# ✅ Batch 386 complete. Progress: 34.4%
# 🔄 Processing batch 387 (5,000 rows)...
# ✅ Batch 387 complete. Progress: 34.5%
# 🔄 Processing batch 388 (5,000 rows)...
# ✅ Batch 388 complete. Progress: 34.5%
# 🔄 Processing batch 389 (5,000 rows)...
# ✅ Batch 389 complete. Progress: 34.6%
# 🔄 Processing batch 390 (5,000 rows)...
# ✅ Batch 390 complete. Progress: 34.7%
# 🔄 Processing batch 391 (5,000 rows)...
# ✅ Batch 391 complete. Progress: 34.8%
# 🔄 Processing batch 392 (5,000 rows)...
# ✅ Batch 392 complete. Progress: 34.9%
# 🔄 Processing batch 393 (5,000 rows)...
# ✅ Batch 393 complete. Progress: 35.0%
# 🔄 Processing batch 394 (5,000 rows)...
# ✅ Batch 394 complete. Progress: 35.1%
# 🔄 Processing batch 395 (5,000 rows)...
# ✅ Batch 395 complete. Progress: 35.2%
# 🔄 Processing batch 396 (5,000 rows)...
# ✅ Batch 396 complete. Progress: 35.3%
# 🔄 Processing batch 397 (5,000 rows)...
# ✅ Batch 397 complete. Progress: 35.3%
# 🔄 Processing batch 398 (5,000 rows)...
# ✅ Batch 398 complete. Progress: 35.4%
# 🔄 Processing batch 399 (5,000 rows)...
# ✅ Batch 399 complete. Progress: 35.5%
# 🔄 Processing batch 400 (5,000 rows)...
# ✅ Batch 400 complete. Progress: 35.6%
# 🔄 Processing batch 401 (5,000 rows)...
# ✅ Batch 401 complete. Progress: 35.7%
# 🔄 Processing batch 402 (5,000 rows)...
# ✅ Batch 402 complete. Progress: 35.8%
# 🔄 Processing batch 403 (5,000 rows)...
# ✅ Batch 403 complete. Progress: 35.9%
# 🔄 Processing batch 404 (5,000 rows)...
# ✅ Batch 404 complete. Progress: 36.0%
# 🔄 Processing batch 405 (5,000 rows)...
# ✅ Batch 405 complete. Progress: 36.1%
# 🔄 Processing batch 406 (5,000 rows)...
# ✅ Batch 406 complete. Progress: 36.1%
# 🔄 Processing batch 407 (5,000 rows)...
# ✅ Batch 407 complete. Progress: 36.2%
# 🔄 Processing batch 408 (5,000 rows)...
# ✅ Batch 408 complete. Progress: 36.3%
# 🔄 Processing batch 409 (5,000 rows)...
# ✅ Batch 409 complete. Progress: 36.4%
# 🔄 Processing batch 410 (5,000 rows)...
# ✅ Batch 410 complete. Progress: 36.5%
# 🔄 Processing batch 411 (5,000 rows)...
# ✅ Batch 411 complete. Progress: 36.6%
# 🔄 Processing batch 412 (5,000 rows)...
# ✅ Batch 412 complete. Progress: 36.7%
# 🔄 Processing batch 413 (5,000 rows)...
# ✅ Batch 413 complete. Progress: 36.8%
# 🔄 Processing batch 414 (5,000 rows)...
# ✅ Batch 414 complete. Progress: 36.9%
# 🔄 Processing batch 415 (5,000 rows)...
# ✅ Batch 415 complete. Progress: 36.9%
# 🔄 Processing batch 416 (5,000 rows)...
# ✅ Batch 416 complete. Progress: 37.0%
# 🔄 Processing batch 417 (5,000 rows)...
# ✅ Batch 417 complete. Progress: 37.1%
# 🔄 Processing batch 418 (5,000 rows)...
# ✅ Batch 418 complete. Progress: 37.2%
# 🔄 Processing batch 419 (5,000 rows)...
# ✅ Batch 419 complete. Progress: 37.3%
# 🔄 Processing batch 420 (5,000 rows)...
# ✅ Batch 420 complete. Progress: 37.4%
# 🔄 Processing batch 421 (5,000 rows)...
# ✅ Batch 421 complete. Progress: 37.5%
# 🔄 Processing batch 422 (5,000 rows)...
# ✅ Batch 422 complete. Progress: 37.6%
# 🔄 Processing batch 423 (5,000 rows)...
# ✅ Batch 423 complete. Progress: 37.7%
# 🔄 Processing batch 424 (5,000 rows)...
# ✅ Batch 424 complete. Progress: 37.7%
# 🔄 Processing batch 425 (5,000 rows)...
# ✅ Batch 425 complete. Progress: 37.8%
# 🔄 Processing batch 426 (5,000 rows)...
# ✅ Batch 426 complete. Progress: 37.9%
# 🔄 Processing batch 427 (5,000 rows)...
# ✅ Batch 427 complete. Progress: 38.0%
# 🔄 Processing batch 428 (5,000 rows)...
# ✅ Batch 428 complete. Progress: 38.1%
# 🔄 Processing batch 429 (5,000 rows)...
# ✅ Batch 429 complete. Progress: 38.2%
# 🔄 Processing batch 430 (5,000 rows)...
# ✅ Batch 430 complete. Progress: 38.3%
# 🔄 Processing batch 431 (5,000 rows)...
# ✅ Batch 431 complete. Progress: 38.4%
# 🔄 Processing batch 432 (5,000 rows)...
# ✅ Batch 432 complete. Progress: 38.5%
# 🔄 Processing batch 433 (5,000 rows)...
# ✅ Batch 433 complete. Progress: 38.5%
# 🔄 Processing batch 434 (5,000 rows)...
# ✅ Batch 434 complete. Progress: 38.6%
# 🔄 Processing batch 435 (5,000 rows)...
# ✅ Batch 435 complete. Progress: 38.7%
# 🔄 Processing batch 436 (5,000 rows)...
# ✅ Batch 436 complete. Progress: 38.8%
# 🔄 Processing batch 437 (5,000 rows)...
# ✅ Batch 437 complete. Progress: 38.9%
# 🔄 Processing batch 438 (5,000 rows)...
# ✅ Batch 438 complete. Progress: 39.0%
# 🔄 Processing batch 439 (5,000 rows)...
# ✅ Batch 439 complete. Progress: 39.1%
# 🔄 Processing batch 440 (5,000 rows)...
# ✅ Batch 440 complete. Progress: 39.2%
# 🔄 Processing batch 441 (5,000 rows)...
# ✅ Batch 441 complete. Progress: 39.3%
# 🔄 Processing batch 442 (5,000 rows)...
# ✅ Batch 442 complete. Progress: 39.3%
# 🔄 Processing batch 443 (5,000 rows)...
# ✅ Batch 443 complete. Progress: 39.4%
# 🔄 Processing batch 444 (5,000 rows)...
# ✅ Batch 444 complete. Progress: 39.5%
# 🔄 Processing batch 445 (5,000 rows)...
# ✅ Batch 445 complete. Progress: 39.6%
# 🔄 Processing batch 446 (5,000 rows)...
# ✅ Batch 446 complete. Progress: 39.7%
# 🔄 Processing batch 447 (5,000 rows)...
# ✅ Batch 447 complete. Progress: 39.8%
# 🔄 Processing batch 448 (5,000 rows)...
# ✅ Batch 448 complete. Progress: 39.9%
# 🔄 Processing batch 449 (5,000 rows)...
# ✅ Batch 449 complete. Progress: 40.0%
# 🔄 Processing batch 450 (5,000 rows)...
# ✅ Batch 450 complete. Progress: 40.1%
# 🔄 Processing batch 451 (5,000 rows)...
# ✅ Batch 451 complete. Progress: 40.1%
# 🔄 Processing batch 452 (5,000 rows)...
# ✅ Batch 452 complete. Progress: 40.2%
# 🔄 Processing batch 453 (5,000 rows)...
# ✅ Batch 453 complete. Progress: 40.3%
# 🔄 Processing batch 454 (5,000 rows)...
# ✅ Batch 454 complete. Progress: 40.4%
# 🔄 Processing batch 455 (5,000 rows)...
# ✅ Batch 455 complete. Progress: 40.5%
# 🔄 Processing batch 456 (5,000 rows)...
# ✅ Batch 456 complete. Progress: 40.6%
# 🔄 Processing batch 457 (5,000 rows)...
# ✅ Batch 457 complete. Progress: 40.7%
# 🔄 Processing batch 458 (5,000 rows)...
# ✅ Batch 458 complete. Progress: 40.8%
# 🔄 Processing batch 459 (5,000 rows)...
# ✅ Batch 459 complete. Progress: 40.9%
# 🔄 Processing batch 460 (5,000 rows)...
# ✅ Batch 460 complete. Progress: 41.0%
# 🔄 Processing batch 461 (5,000 rows)...
# ✅ Batch 461 complete. Progress: 41.0%
# 🔄 Processing batch 462 (5,000 rows)...
# ✅ Batch 462 complete. Progress: 41.1%
# 🔄 Processing batch 463 (5,000 rows)...
# ✅ Batch 463 complete. Progress: 41.2%
# 🔄 Processing batch 464 (5,000 rows)...
# ✅ Batch 464 complete. Progress: 41.3%
# 🔄 Processing batch 465 (5,000 rows)...
# ✅ Batch 465 complete. Progress: 41.4%
# 🔄 Processing batch 466 (5,000 rows)...
# ✅ Batch 466 complete. Progress: 41.5%
# 🔄 Processing batch 467 (5,000 rows)...
# ✅ Batch 467 complete. Progress: 41.6%
# 🔄 Processing batch 468 (5,000 rows)...
# ✅ Batch 468 complete. Progress: 41.7%
# 🔄 Processing batch 469 (5,000 rows)...
# ✅ Batch 469 complete. Progress: 41.8%
# 🔄 Processing batch 470 (5,000 rows)...
# ✅ Batch 470 complete. Progress: 41.8%
# 🔄 Processing batch 471 (5,000 rows)...
# ✅ Batch 471 complete. Progress: 41.9%
# 🔄 Processing batch 472 (5,000 rows)...
# ✅ Batch 472 complete. Progress: 42.0%
# 🔄 Processing batch 473 (5,000 rows)...
# ✅ Batch 473 complete. Progress: 42.1%
# 🔄 Processing batch 474 (5,000 rows)...
# ✅ Batch 474 complete. Progress: 42.2%
# 🔄 Processing batch 475 (5,000 rows)...
# ✅ Batch 475 complete. Progress: 42.3%
# 🔄 Processing batch 476 (5,000 rows)...
# ✅ Batch 476 complete. Progress: 42.4%
# 🔄 Processing batch 477 (5,000 rows)...
# ✅ Batch 477 complete. Progress: 42.5%
# 🔄 Processing batch 478 (5,000 rows)...
# ✅ Batch 478 complete. Progress: 42.6%
# 🔄 Processing batch 479 (5,000 rows)...
# ✅ Batch 479 complete. Progress: 42.6%
# 🔄 Processing batch 480 (5,000 rows)...
# ✅ Batch 480 complete. Progress: 42.7%
# 🔄 Processing batch 481 (5,000 rows)...
# ✅ Batch 481 complete. Progress: 42.8%
# 🔄 Processing batch 482 (5,000 rows)...
# ✅ Batch 482 complete. Progress: 42.9%
# 🔄 Processing batch 483 (5,000 rows)...
# ✅ Batch 483 complete. Progress: 43.0%
# 🔄 Processing batch 484 (5,000 rows)...
# ✅ Batch 484 complete. Progress: 43.1%
# 🔄 Processing batch 485 (5,000 rows)...
# ✅ Batch 485 complete. Progress: 43.2%
# 🔄 Processing batch 486 (5,000 rows)...
# ✅ Batch 486 complete. Progress: 43.3%
# 🔄 Processing batch 487 (5,000 rows)...
# ✅ Batch 487 complete. Progress: 43.4%
# 🔄 Processing batch 488 (5,000 rows)...
# ✅ Batch 488 complete. Progress: 43.4%
# 🔄 Processing batch 489 (5,000 rows)...
# ✅ Batch 489 complete. Progress: 43.5%
# 🔄 Processing batch 490 (5,000 rows)...
# ✅ Batch 490 complete. Progress: 43.6%
# 🔄 Processing batch 491 (5,000 rows)...
# ✅ Batch 491 complete. Progress: 43.7%
# 🔄 Processing batch 492 (5,000 rows)...
# ✅ Batch 492 complete. Progress: 43.8%
# 🔄 Processing batch 493 (5,000 rows)...
# ✅ Batch 493 complete. Progress: 43.9%
# 🔄 Processing batch 494 (5,000 rows)...
# ✅ Batch 494 complete. Progress: 44.0%
# 🔄 Processing batch 495 (5,000 rows)...
# ✅ Batch 495 complete. Progress: 44.1%
# 🔄 Processing batch 496 (5,000 rows)...
# ✅ Batch 496 complete. Progress: 44.2%
# 🔄 Processing batch 497 (5,000 rows)...
# ✅ Batch 497 complete. Progress: 44.2%
# 🔄 Processing batch 498 (5,000 rows)...
# ✅ Batch 498 complete. Progress: 44.3%
# 🔄 Processing batch 499 (5,000 rows)...
# ✅ Batch 499 complete. Progress: 44.4%
# 🔄 Processing batch 500 (5,000 rows)...
# ✅ Batch 500 complete. Progress: 44.5%
# 🔄 Processing batch 501 (5,000 rows)...
# ✅ Batch 501 complete. Progress: 44.6%
# 🔄 Processing batch 502 (5,000 rows)...
# ✅ Batch 502 complete. Progress: 44.7%
# 🔄 Processing batch 503 (5,000 rows)...
# ✅ Batch 503 complete. Progress: 44.8%
# 🔄 Processing batch 504 (5,000 rows)...
# ✅ Batch 504 complete. Progress: 44.9%
# 🔄 Processing batch 505 (5,000 rows)...
# ✅ Batch 505 complete. Progress: 45.0%
# 🔄 Processing batch 506 (5,000 rows)...
# ✅ Batch 506 complete. Progress: 45.0%
# 🔄 Processing batch 507 (5,000 rows)...
# ✅ Batch 507 complete. Progress: 45.1%
# 🔄 Processing batch 508 (5,000 rows)...
# ✅ Batch 508 complete. Progress: 45.2%
# 🔄 Processing batch 509 (5,000 rows)...
# ✅ Batch 509 complete. Progress: 45.3%
# 🔄 Processing batch 510 (5,000 rows)...
# ✅ Batch 510 complete. Progress: 45.4%
# 🔄 Processing batch 511 (5,000 rows)...
# ✅ Batch 511 complete. Progress: 45.5%
# 🔄 Processing batch 512 (5,000 rows)...
# ✅ Batch 512 complete. Progress: 45.6%
# 🔄 Processing batch 513 (5,000 rows)...
# ✅ Batch 513 complete. Progress: 45.7%
# 🔄 Processing batch 514 (5,000 rows)...
# ✅ Batch 514 complete. Progress: 45.8%
# 🔄 Processing batch 515 (5,000 rows)...
# ✅ Batch 515 complete. Progress: 45.8%
# 🔄 Processing batch 516 (5,000 rows)...
# ✅ Batch 516 complete. Progress: 45.9%
# 🔄 Processing batch 517 (5,000 rows)...
# ✅ Batch 517 complete. Progress: 46.0%
# 🔄 Processing batch 518 (5,000 rows)...
# ✅ Batch 518 complete. Progress: 46.1%
# 🔄 Processing batch 519 (5,000 rows)...
# ✅ Batch 519 complete. Progress: 46.2%
# 🔄 Processing batch 520 (5,000 rows)...
# ✅ Batch 520 complete. Progress: 46.3%
# 🔄 Processing batch 521 (5,000 rows)...
# ✅ Batch 521 complete. Progress: 46.4%
# 🔄 Processing batch 522 (5,000 rows)...
# ✅ Batch 522 complete. Progress: 46.5%
# 🔄 Processing batch 523 (5,000 rows)...
# ✅ Batch 523 complete. Progress: 46.6%
# 🔄 Processing batch 524 (5,000 rows)...
# ✅ Batch 524 complete. Progress: 46.6%
# 🔄 Processing batch 525 (5,000 rows)...
# ✅ Batch 525 complete. Progress: 46.7%
# 🔄 Processing batch 526 (5,000 rows)...
# ✅ Batch 526 complete. Progress: 46.8%
# 🔄 Processing batch 527 (5,000 rows)...
# ✅ Batch 527 complete. Progress: 46.9%
# 🔄 Processing batch 528 (5,000 rows)...
# ✅ Batch 528 complete. Progress: 47.0%
# 🔄 Processing batch 529 (5,000 rows)...
# ✅ Batch 529 complete. Progress: 47.1%
# 🔄 Processing batch 530 (5,000 rows)...
# ✅ Batch 530 complete. Progress: 47.2%
# 🔄 Processing batch 531 (5,000 rows)...
# ✅ Batch 531 complete. Progress: 47.3%
# 🔄 Processing batch 532 (5,000 rows)...
# ✅ Batch 532 complete. Progress: 47.4%
# 🔄 Processing batch 533 (5,000 rows)...
# ✅ Batch 533 complete. Progress: 47.4%
# 🔄 Processing batch 534 (5,000 rows)...
# ✅ Batch 534 complete. Progress: 47.5%
# 🔄 Processing batch 535 (5,000 rows)...
# ✅ Batch 535 complete. Progress: 47.6%
# 🔄 Processing batch 536 (5,000 rows)...
# ✅ Batch 536 complete. Progress: 47.7%
# 🔄 Processing batch 537 (5,000 rows)...
# ✅ Batch 537 complete. Progress: 47.8%
# 🔄 Processing batch 538 (5,000 rows)...
# ✅ Batch 538 complete. Progress: 47.9%
# 🔄 Processing batch 539 (5,000 rows)...
# ✅ Batch 539 complete. Progress: 48.0%
# 🔄 Processing batch 540 (5,000 rows)...
# ✅ Batch 540 complete. Progress: 48.1%
# 🔄 Processing batch 541 (5,000 rows)...
# ✅ Batch 541 complete. Progress: 48.2%
# 🔄 Processing batch 542 (5,000 rows)...
# ✅ Batch 542 complete. Progress: 48.3%
# 🔄 Processing batch 543 (5,000 rows)...
# ✅ Batch 543 complete. Progress: 48.3%
# 🔄 Processing batch 544 (5,000 rows)...
# ✅ Batch 544 complete. Progress: 48.4%
# 🔄 Processing batch 545 (5,000 rows)...
# ✅ Batch 545 complete. Progress: 48.5%
# 🔄 Processing batch 546 (5,000 rows)...
# ✅ Batch 546 complete. Progress: 48.6%
# 🔄 Processing batch 547 (5,000 rows)...
# ✅ Batch 547 complete. Progress: 48.7%
# 🔄 Processing batch 548 (5,000 rows)...
# ✅ Batch 548 complete. Progress: 48.8%
# 🔄 Processing batch 549 (5,000 rows)...
# ✅ Batch 549 complete. Progress: 48.9%
# 🔄 Processing batch 550 (5,000 rows)...
# ✅ Batch 550 complete. Progress: 49.0%
# 🔄 Processing batch 551 (5,000 rows)...
# ✅ Batch 551 complete. Progress: 49.1%
# 🔄 Processing batch 552 (5,000 rows)...
# ✅ Batch 552 complete. Progress: 49.1%
# 🔄 Processing batch 553 (5,000 rows)...
# ✅ Batch 553 complete. Progress: 49.2%
# 🔄 Processing batch 554 (5,000 rows)...
# ✅ Batch 554 complete. Progress: 49.3%
# 🔄 Processing batch 555 (5,000 rows)...
# ✅ Batch 555 complete. Progress: 49.4%
# 🔄 Processing batch 556 (5,000 rows)...
# ✅ Batch 556 complete. Progress: 49.5%
# 🔄 Processing batch 557 (5,000 rows)...
# ✅ Batch 557 complete. Progress: 49.6%
# 🔄 Processing batch 558 (5,000 rows)...
# ✅ Batch 558 complete. Progress: 49.7%
# 🔄 Processing batch 559 (5,000 rows)...
# ✅ Batch 559 complete. Progress: 49.8%
# 🔄 Processing batch 560 (5,000 rows)...
# ✅ Batch 560 complete. Progress: 49.9%
# 🔄 Processing batch 561 (5,000 rows)...
# ✅ Batch 561 complete. Progress: 49.9%
# 🔄 Processing batch 562 (5,000 rows)...
# ✅ Batch 562 complete. Progress: 50.0%
# 🔄 Processing batch 563 (5,000 rows)...
# ✅ Batch 563 complete. Progress: 50.1%
# 🔄 Processing batch 564 (5,000 rows)...
# ✅ Batch 564 complete. Progress: 50.2%
# 🔄 Processing batch 565 (5,000 rows)...
# ✅ Batch 565 complete. Progress: 50.3%
# 🔄 Processing batch 566 (5,000 rows)...
# ✅ Batch 566 complete. Progress: 50.4%
# 🔄 Processing batch 567 (5,000 rows)...
# ✅ Batch 567 complete. Progress: 50.5%
# 🔄 Processing batch 568 (5,000 rows)...
# ✅ Batch 568 complete. Progress: 50.6%
# 🔄 Processing batch 569 (5,000 rows)...
# ✅ Batch 569 complete. Progress: 50.7%
# 🔄 Processing batch 570 (5,000 rows)...
# ✅ Batch 570 complete. Progress: 50.7%
# 🔄 Processing batch 571 (5,000 rows)...
# ✅ Batch 571 complete. Progress: 50.8%
# 🔄 Processing batch 572 (5,000 rows)...
# ✅ Batch 572 complete. Progress: 50.9%
# 🔄 Processing batch 573 (5,000 rows)...
# ✅ Batch 573 complete. Progress: 51.0%
# 🔄 Processing batch 574 (5,000 rows)...
# ✅ Batch 574 complete. Progress: 51.1%
# 🔄 Processing batch 575 (5,000 rows)...
# ✅ Batch 575 complete. Progress: 51.2%
# 🔄 Processing batch 576 (5,000 rows)...
# ✅ Batch 576 complete. Progress: 51.3%
# 🔄 Processing batch 577 (5,000 rows)...
# ✅ Batch 577 complete. Progress: 51.4%
# 🔄 Processing batch 578 (5,000 rows)...
# ✅ Batch 578 complete. Progress: 51.5%
# 🔄 Processing batch 579 (5,000 rows)...
# ✅ Batch 579 complete. Progress: 51.5%
# 🔄 Processing batch 580 (5,000 rows)...
# ✅ Batch 580 complete. Progress: 51.6%
# 🔄 Processing batch 581 (5,000 rows)...
# ✅ Batch 581 complete. Progress: 51.7%
# 🔄 Processing batch 582 (5,000 rows)...
# ✅ Batch 582 complete. Progress: 51.8%
# 🔄 Processing batch 583 (5,000 rows)...
# ✅ Batch 583 complete. Progress: 51.9%
# 🔄 Processing batch 584 (5,000 rows)...
# ✅ Batch 584 complete. Progress: 52.0%
# 🔄 Processing batch 585 (5,000 rows)...
# ✅ Batch 585 complete. Progress: 52.1%
# 🔄 Processing batch 586 (5,000 rows)...
# ✅ Batch 586 complete. Progress: 52.2%
# 🔄 Processing batch 587 (5,000 rows)...
# ✅ Batch 587 complete. Progress: 52.3%
# 🔄 Processing batch 588 (5,000 rows)...
# ✅ Batch 588 complete. Progress: 52.3%
# 🔄 Processing batch 589 (5,000 rows)...
# ✅ Batch 589 complete. Progress: 52.4%
# 🔄 Processing batch 590 (5,000 rows)...
# ✅ Batch 590 complete. Progress: 52.5%
# 🔄 Processing batch 591 (5,000 rows)...
# ✅ Batch 591 complete. Progress: 52.6%
# 🔄 Processing batch 592 (5,000 rows)...
# ✅ Batch 592 complete. Progress: 52.7%
# 🔄 Processing batch 593 (5,000 rows)...
# ✅ Batch 593 complete. Progress: 52.8%
# 🔄 Processing batch 594 (5,000 rows)...
# ✅ Batch 594 complete. Progress: 52.9%
# 🔄 Processing batch 595 (5,000 rows)...
# ✅ Batch 595 complete. Progress: 53.0%
# 🔄 Processing batch 596 (5,000 rows)...
# ✅ Batch 596 complete. Progress: 53.1%
# 🔄 Processing batch 597 (5,000 rows)...
# ✅ Batch 597 complete. Progress: 53.1%
# 🔄 Processing batch 598 (5,000 rows)...
# ✅ Batch 598 complete. Progress: 53.2%
# 🔄 Processing batch 599 (5,000 rows)...
# ✅ Batch 599 complete. Progress: 53.3%
# 🔄 Processing batch 600 (5,000 rows)...
# ✅ Batch 600 complete. Progress: 53.4%
# 🔄 Processing batch 601 (5,000 rows)...
# ✅ Batch 601 complete. Progress: 53.5%
# 🔄 Processing batch 602 (5,000 rows)...
# ✅ Batch 602 complete. Progress: 53.6%
# 🔄 Processing batch 603 (5,000 rows)...
# ✅ Batch 603 complete. Progress: 53.7%
# 🔄 Processing batch 604 (5,000 rows)...
# ✅ Batch 604 complete. Progress: 53.8%
# 🔄 Processing batch 605 (5,000 rows)...
# ✅ Batch 605 complete. Progress: 53.9%
# 🔄 Processing batch 606 (5,000 rows)...
# ✅ Batch 606 complete. Progress: 53.9%
# 🔄 Processing batch 607 (5,000 rows)...
# ✅ Batch 607 complete. Progress: 54.0%
# 🔄 Processing batch 608 (5,000 rows)...
# ✅ Batch 608 complete. Progress: 54.1%
# 🔄 Processing batch 609 (5,000 rows)...
# ✅ Batch 609 complete. Progress: 54.2%
# 🔄 Processing batch 610 (5,000 rows)...
# ✅ Batch 610 complete. Progress: 54.3%
# 🔄 Processing batch 611 (5,000 rows)...
# ✅ Batch 611 complete. Progress: 54.4%
# 🔄 Processing batch 612 (5,000 rows)...
# ✅ Batch 612 complete. Progress: 54.5%
# 🔄 Processing batch 613 (5,000 rows)...
# ✅ Batch 613 complete. Progress: 54.6%
# 🔄 Processing batch 614 (5,000 rows)...
# ✅ Batch 614 complete. Progress: 54.7%
# 🔄 Processing batch 615 (5,000 rows)...
# ✅ Batch 615 complete. Progress: 54.7%
# 🔄 Processing batch 616 (5,000 rows)...
# ✅ Batch 616 complete. Progress: 54.8%
# 🔄 Processing batch 617 (5,000 rows)...
# ✅ Batch 617 complete. Progress: 54.9%
# 🔄 Processing batch 618 (5,000 rows)...
# ✅ Batch 618 complete. Progress: 55.0%
# 🔄 Processing batch 619 (5,000 rows)...
# ✅ Batch 619 complete. Progress: 55.1%
# 🔄 Processing batch 620 (5,000 rows)...
# ✅ Batch 620 complete. Progress: 55.2%
# 🔄 Processing batch 621 (5,000 rows)...
# ✅ Batch 621 complete. Progress: 55.3%
# 🔄 Processing batch 622 (5,000 rows)...
# ✅ Batch 622 complete. Progress: 55.4%
# ...
# ✅ Batch 923 complete. Progress: 82.2%
# 🔄 Processing batch 924 (5,000 rows)...
# ✅ Batch 924 complete. Progress: 82.3%
# 🔄 Processing batch 925 (5,000 rows)...
# ✅ Batch 925 complete. Progress: 82.3%
# 🔄 Processing batch 926 (5,000 rows)...
# ✅ Batch 926 complete. Progress: 82.4%
# 🔄 Processing batch 927 (5,000 rows)...
# ✅ Batch 927 complete. Progress: 82.5%
# 🔄 Processing batch 928 (5,000 rows)...
# ✅ Batch 928 complete. Progress: 82.6%
# 🔄 Processing batch 929 (5,000 rows)...
# ✅ Batch 929 complete. Progress: 82.7%
# 🔄 Processing batch 930 (5,000 rows)...
# ✅ Batch 930 complete. Progress: 82.8%
# 🔄 Processing batch 931 (5,000 rows)...
# ✅ Batch 931 complete. Progress: 82.9%
# 🔄 Processing batch 932 (5,000 rows)...
# ✅ Batch 932 complete. Progress: 83.0%
# 🔄 Processing batch 933 (5,000 rows)...
# ✅ Batch 933 complete. Progress: 83.1%
# 🔄 Processing batch 934 (5,000 rows)...
# ✅ Batch 934 complete. Progress: 83.1%
# 🔄 Processing batch 935 (5,000 rows)...
# ✅ Batch 935 complete. Progress: 83.2%
# 🔄 Processing batch 936 (5,000 rows)...
# ✅ Batch 936 complete. Progress: 83.3%
# 🔄 Processing batch 937 (5,000 rows)...
# ✅ Batch 937 complete. Progress: 83.4%
# 🔄 Processing batch 938 (5,000 rows)...
# ✅ Batch 938 complete. Progress: 83.5%
# 🔄 Processing batch 939 (5,000 rows)...
# ✅ Batch 939 complete. Progress: 83.6%
# 🔄 Processing batch 940 (5,000 rows)...
# ✅ Batch 940 complete. Progress: 83.7%
# 🔄 Processing batch 941 (5,000 rows)...
# ✅ Batch 941 complete. Progress: 83.8%
# 🔄 Processing batch 942 (5,000 rows)...
# ✅ Batch 942 complete. Progress: 83.9%
# 🔄 Processing batch 943 (5,000 rows)...
# ✅ Batch 943 complete. Progress: 83.9%
# 🔄 Processing batch 944 (5,000 rows)...
# ✅ Batch 944 complete. Progress: 84.0%
# 🔄 Processing batch 945 (5,000 rows)...
# ✅ Batch 945 complete. Progress: 84.1%
# 🔄 Processing batch 946 (5,000 rows)...
# ✅ Batch 946 complete. Progress: 84.2%
# 🔄 Processing batch 947 (5,000 rows)...
# ✅ Batch 947 complete. Progress: 84.3%
# 🔄 Processing batch 948 (5,000 rows)...
# ✅ Batch 948 complete. Progress: 84.4%
# 🔄 Processing batch 949 (5,000 rows)...
# ✅ Batch 949 complete. Progress: 84.5%
# 🔄 Processing batch 950 (5,000 rows)...
# ✅ Batch 950 complete. Progress: 84.6%
# 🔄 Processing batch 951 (5,000 rows)...
# ✅ Batch 951 complete. Progress: 84.7%
# 🔄 Processing batch 952 (5,000 rows)...
# ✅ Batch 952 complete. Progress: 84.8%
# 🔄 Processing batch 953 (5,000 rows)...
# ✅ Batch 953 complete. Progress: 84.8%
# 🔄 Processing batch 954 (5,000 rows)...
# ✅ Batch 954 complete. Progress: 84.9%
# 🔄 Processing batch 955 (5,000 rows)...
# ✅ Batch 955 complete. Progress: 85.0%
# 🔄 Processing batch 956 (5,000 rows)...
# ✅ Batch 956 complete. Progress: 85.1%
# 🔄 Processing batch 957 (5,000 rows)...
# ✅ Batch 957 complete. Progress: 85.2%
# 🔄 Processing batch 958 (5,000 rows)...
# ✅ Batch 958 complete. Progress: 85.3%
# 🔄 Processing batch 959 (5,000 rows)...
# ✅ Batch 959 complete. Progress: 85.4%
# 🔄 Processing batch 960 (5,000 rows)...
# ✅ Batch 960 complete. Progress: 85.5%
# 🔄 Processing batch 961 (5,000 rows)...
# ✅ Batch 961 complete. Progress: 85.6%
# 🔄 Processing batch 962 (5,000 rows)...
# ✅ Batch 962 complete. Progress: 85.6%
# 🔄 Processing batch 963 (5,000 rows)...
# ✅ Batch 963 complete. Progress: 85.7%
# 🔄 Processing batch 964 (5,000 rows)...
# ✅ Batch 964 complete. Progress: 85.8%
# 🔄 Processing batch 965 (5,000 rows)...
# ✅ Batch 965 complete. Progress: 85.9%
# 🔄 Processing batch 966 (5,000 rows)...
# ✅ Batch 966 complete. Progress: 86.0%
# 🔄 Processing batch 967 (5,000 rows)...
# ✅ Batch 967 complete. Progress: 86.1%
# 🔄 Processing batch 968 (5,000 rows)...
# ✅ Batch 968 complete. Progress: 86.2%
# 🔄 Processing batch 969 (5,000 rows)...
# ✅ Batch 969 complete. Progress: 86.3%
# 🔄 Processing batch 970 (5,000 rows)...
# ✅ Batch 970 complete. Progress: 86.4%
# 🔄 Processing batch 971 (5,000 rows)...
# ✅ Batch 971 complete. Progress: 86.4%
# 🔄 Processing batch 972 (5,000 rows)...
# ✅ Batch 972 complete. Progress: 86.5%
# 🔄 Processing batch 973 (5,000 rows)...
# ✅ Batch 973 complete. Progress: 86.6%
# 🔄 Processing batch 974 (5,000 rows)...
# ✅ Batch 974 complete. Progress: 86.7%
# 🔄 Processing batch 975 (5,000 rows)...
# ✅ Batch 975 complete. Progress: 86.8%
# 🔄 Processing batch 976 (5,000 rows)...
# ✅ Batch 976 complete. Progress: 86.9%
# 🔄 Processing batch 977 (5,000 rows)...
# ✅ Batch 977 complete. Progress: 87.0%
# 🔄 Processing batch 978 (5,000 rows)...
# ✅ Batch 978 complete. Progress: 87.1%
# 🔄 Processing batch 979 (5,000 rows)...
# ✅ Batch 979 complete. Progress: 87.2%
# 🔄 Processing batch 980 (5,000 rows)...
# ✅ Batch 980 complete. Progress: 87.2%
# 🔄 Processing batch 981 (5,000 rows)...
# ✅ Batch 981 complete. Progress: 87.3%
# 🔄 Processing batch 982 (5,000 rows)...
# ✅ Batch 982 complete. Progress: 87.4%
# 🔄 Processing batch 983 (5,000 rows)...
# ✅ Batch 983 complete. Progress: 87.5%
# 🔄 Processing batch 984 (5,000 rows)...
# ✅ Batch 984 complete. Progress: 87.6%
# 🔄 Processing batch 985 (5,000 rows)...
# ✅ Batch 985 complete. Progress: 87.7%
# 🔄 Processing batch 986 (5,000 rows)...
# ✅ Batch 986 complete. Progress: 87.8%
# 🔄 Processing batch 987 (5,000 rows)...
# ✅ Batch 987 complete. Progress: 87.9%
# 🔄 Processing batch 988 (5,000 rows)...
# ✅ Batch 988 complete. Progress: 88.0%
# 🔄 Processing batch 989 (5,000 rows)...
# ✅ Batch 989 complete. Progress: 88.0%
# 🔄 Processing batch 990 (5,000 rows)...
# ✅ Batch 990 complete. Progress: 88.1%
# 🔄 Processing batch 991 (5,000 rows)...
# ✅ Batch 991 complete. Progress: 88.2%
# 🔄 Processing batch 992 (5,000 rows)...
# ✅ Batch 992 complete. Progress: 88.3%
# 🔄 Processing batch 993 (5,000 rows)...
# ✅ Batch 993 complete. Progress: 88.4%
# 🔄 Processing batch 994 (5,000 rows)...
# ✅ Batch 994 complete. Progress: 88.5%
# 🔄 Processing batch 995 (5,000 rows)...
# ✅ Batch 995 complete. Progress: 88.6%
# 🔄 Processing batch 996 (5,000 rows)...
# ✅ Batch 996 complete. Progress: 88.7%
# 🔄 Processing batch 997 (5,000 rows)...
# ✅ Batch 997 complete. Progress: 88.8%
# 🔄 Processing batch 998 (5,000 rows)...
# ✅ Batch 998 complete. Progress: 88.8%
# 🔄 Processing batch 999 (5,000 rows)...
# ✅ Batch 999 complete. Progress: 88.9%
# 🔄 Processing batch 1000 (5,000 rows)...
# ✅ Batch 1000 complete. Progress: 89.0%
# 🔄 Processing batch 1001 (5,000 rows)...
# ✅ Batch 1001 complete. Progress: 89.1%
# 🔄 Processing batch 1002 (5,000 rows)...
# ✅ Batch 1002 complete. Progress: 89.2%
# 🔄 Processing batch 1003 (5,000 rows)...
# ✅ Batch 1003 complete. Progress: 89.3%
# 🔄 Processing batch 1004 (5,000 rows)...
# ✅ Batch 1004 complete. Progress: 89.4%
# 🔄 Processing batch 1005 (5,000 rows)...
# ✅ Batch 1005 complete. Progress: 89.5%
# 🔄 Processing batch 1006 (5,000 rows)...
# ✅ Batch 1006 complete. Progress: 89.6%
# 🔄 Processing batch 1007 (5,000 rows)...
# ✅ Batch 1007 complete. Progress: 89.6%
# 🔄 Processing batch 1008 (5,000 rows)...
# ✅ Batch 1008 complete. Progress: 89.7%
# 🔄 Processing batch 1009 (5,000 rows)...
# ✅ Batch 1009 complete. Progress: 89.8%
# 🔄 Processing batch 1010 (5,000 rows)...
# ✅ Batch 1010 complete. Progress: 89.9%
# 🔄 Processing batch 1011 (5,000 rows)...
# ✅ Batch 1011 complete. Progress: 90.0%
# 🔄 Processing batch 1012 (5,000 rows)...
# ✅ Batch 1012 complete. Progress: 90.1%
# 🔄 Processing batch 1013 (5,000 rows)...
# ✅ Batch 1013 complete. Progress: 90.2%
# 🔄 Processing batch 1014 (5,000 rows)...
# ✅ Batch 1014 complete. Progress: 90.3%
# 🔄 Processing batch 1015 (5,000 rows)...
# ✅ Batch 1015 complete. Progress: 90.4%
# 🔄 Processing batch 1016 (5,000 rows)...
# ✅ Batch 1016 complete. Progress: 90.4%
# 🔄 Processing batch 1017 (5,000 rows)...
# ✅ Batch 1017 complete. Progress: 90.5%
# 🔄 Processing batch 1018 (5,000 rows)...
# ✅ Batch 1018 complete. Progress: 90.6%
# 🔄 Processing batch 1019 (5,000 rows)...
# ✅ Batch 1019 complete. Progress: 90.7%
# 🔄 Processing batch 1020 (5,000 rows)...
# ✅ Batch 1020 complete. Progress: 90.8%
# 🔄 Processing batch 1021 (5,000 rows)...
# ✅ Batch 1021 complete. Progress: 90.9%
# 🔄 Processing batch 1022 (5,000 rows)...
# ✅ Batch 1022 complete. Progress: 91.0%
# 🔄 Processing batch 1023 (5,000 rows)...
# ✅ Batch 1023 complete. Progress: 91.1%
# 🔄 Processing batch 1024 (5,000 rows)...
# ✅ Batch 1024 complete. Progress: 91.2%
# 🔄 Processing batch 1025 (5,000 rows)...
# ✅ Batch 1025 complete. Progress: 91.2%
# 🔄 Processing batch 1026 (5,000 rows)...
# ✅ Batch 1026 complete. Progress: 91.3%
# 🔄 Processing batch 1027 (5,000 rows)...
# ✅ Batch 1027 complete. Progress: 91.4%
# 🔄 Processing batch 1028 (5,000 rows)...
# ✅ Batch 1028 complete. Progress: 91.5%
# 🔄 Processing batch 1029 (5,000 rows)...
# ✅ Batch 1029 complete. Progress: 91.6%
# 🔄 Processing batch 1030 (5,000 rows)...
# ✅ Batch 1030 complete. Progress: 91.7%
# 🔄 Processing batch 1031 (5,000 rows)...
# ✅ Batch 1031 complete. Progress: 91.8%
# 🔄 Processing batch 1032 (5,000 rows)...
# ✅ Batch 1032 complete. Progress: 91.9%
# 🔄 Processing batch 1033 (5,000 rows)...
# ✅ Batch 1033 complete. Progress: 92.0%
# 🔄 Processing batch 1034 (5,000 rows)...
# ✅ Batch 1034 complete. Progress: 92.1%
# 🔄 Processing batch 1035 (5,000 rows)...
# ✅ Batch 1035 complete. Progress: 92.1%
# 🔄 Processing batch 1036 (5,000 rows)...
# ✅ Batch 1036 complete. Progress: 92.2%
# 🔄 Processing batch 1037 (5,000 rows)...
# ✅ Batch 1037 complete. Progress: 92.3%
# 🔄 Processing batch 1038 (5,000 rows)...
# ✅ Batch 1038 complete. Progress: 92.4%
# 🔄 Processing batch 1039 (5,000 rows)...
# ✅ Batch 1039 complete. Progress: 92.5%
# 🔄 Processing batch 1040 (5,000 rows)...
# ✅ Batch 1040 complete. Progress: 92.6%
# 🔄 Processing batch 1041 (5,000 rows)...
# ✅ Batch 1041 complete. Progress: 92.7%
# 🔄 Processing batch 1042 (5,000 rows)...
# ✅ Batch 1042 complete. Progress: 92.8%
# 🔄 Processing batch 1043 (5,000 rows)...
# ✅ Batch 1043 complete. Progress: 92.9%
# 🔄 Processing batch 1044 (5,000 rows)...
# ✅ Batch 1044 complete. Progress: 92.9%
# 🔄 Processing batch 1045 (5,000 rows)...
# ✅ Batch 1045 complete. Progress: 93.0%
# 🔄 Processing batch 1046 (5,000 rows)...
# ✅ Batch 1046 complete. Progress: 93.1%
# 🔄 Processing batch 1047 (5,000 rows)...
# ✅ Batch 1047 complete. Progress: 93.2%
# 🔄 Processing batch 1048 (5,000 rows)...
# ✅ Batch 1048 complete. Progress: 93.3%
# 🔄 Processing batch 1049 (5,000 rows)...
# ✅ Batch 1049 complete. Progress: 93.4%
# 🔄 Processing batch 1050 (5,000 rows)...
# ✅ Batch 1050 complete. Progress: 93.5%
# 🔄 Processing batch 1051 (5,000 rows)...
# ✅ Batch 1051 complete. Progress: 93.6%
# 🔄 Processing batch 1052 (5,000 rows)...
# ✅ Batch 1052 complete. Progress: 93.7%
# 🔄 Processing batch 1053 (5,000 rows)...
# ✅ Batch 1053 complete. Progress: 93.7%
# 🔄 Processing batch 1054 (5,000 rows)...
# ✅ Batch 1054 complete. Progress: 93.8%
# 🔄 Processing batch 1055 (5,000 rows)...
# ✅ Batch 1055 complete. Progress: 93.9%
# 🔄 Processing batch 1056 (5,000 rows)...
# ✅ Batch 1056 complete. Progress: 94.0%
# 🔄 Processing batch 1057 (5,000 rows)...
# ✅ Batch 1057 complete. Progress: 94.1%
# 🔄 Processing batch 1058 (5,000 rows)...
# ✅ Batch 1058 complete. Progress: 94.2%
# 🔄 Processing batch 1059 (5,000 rows)...
# ✅ Batch 1059 complete. Progress: 94.3%
# 🔄 Processing batch 1060 (5,000 rows)...
# ✅ Batch 1060 complete. Progress: 94.4%
# 🔄 Processing batch 1061 (5,000 rows)...
# ✅ Batch 1061 complete. Progress: 94.5%
# 🔄 Processing batch 1062 (5,000 rows)...
# ✅ Batch 1062 complete. Progress: 94.5%
# 🔄 Processing batch 1063 (5,000 rows)...
# ✅ Batch 1063 complete. Progress: 94.6%
# 🔄 Processing batch 1064 (5,000 rows)...
# ✅ Batch 1064 complete. Progress: 94.7%
# 🔄 Processing batch 1065 (5,000 rows)...
# ✅ Batch 1065 complete. Progress: 94.8%
# 🔄 Processing batch 1066 (5,000 rows)...
# ✅ Batch 1066 complete. Progress: 94.9%
# 🔄 Processing batch 1067 (5,000 rows)...
# ✅ Batch 1067 complete. Progress: 95.0%
# 🔄 Processing batch 1068 (5,000 rows)...
# ✅ Batch 1068 complete. Progress: 95.1%
# 🔄 Processing batch 1069 (5,000 rows)...
# ✅ Batch 1069 complete. Progress: 95.2%
# 🔄 Processing batch 1070 (5,000 rows)...
# ✅ Batch 1070 complete. Progress: 95.3%
# 🔄 Processing batch 1071 (5,000 rows)...
# ✅ Batch 1071 complete. Progress: 95.3%
# 🔄 Processing batch 1072 (5,000 rows)...
# ✅ Batch 1072 complete. Progress: 95.4%
# 🔄 Processing batch 1073 (5,000 rows)...
# ✅ Batch 1073 complete. Progress: 95.5%
# 🔄 Processing batch 1074 (5,000 rows)...
# ✅ Batch 1074 complete. Progress: 95.6%
# 🔄 Processing batch 1075 (5,000 rows)...
# ✅ Batch 1075 complete. Progress: 95.7%
# 🔄 Processing batch 1076 (5,000 rows)...
# ✅ Batch 1076 complete. Progress: 95.8%
# 🔄 Processing batch 1077 (5,000 rows)...
# ✅ Batch 1077 complete. Progress: 95.9%
# 🔄 Processing batch 1078 (5,000 rows)...
# ✅ Batch 1078 complete. Progress: 96.0%
# 🔄 Processing batch 1079 (5,000 rows)...
# ✅ Batch 1079 complete. Progress: 96.1%
# 🔄 Processing batch 1080 (5,000 rows)...
# ✅ Batch 1080 complete. Progress: 96.1%
# 🔄 Processing batch 1081 (5,000 rows)...
# ✅ Batch 1081 complete. Progress: 96.2%
# 🔄 Processing batch 1082 (5,000 rows)...
# ✅ Batch 1082 complete. Progress: 96.3%
# 🔄 Processing batch 1083 (5,000 rows)...
# ✅ Batch 1083 complete. Progress: 96.4%
# 🔄 Processing batch 1084 (5,000 rows)...
# ✅ Batch 1084 complete. Progress: 96.5%
# 🔄 Processing batch 1085 (5,000 rows)...
# ✅ Batch 1085 complete. Progress: 96.6%
# 🔄 Processing batch 1086 (5,000 rows)...
# ✅ Batch 1086 complete. Progress: 96.7%
# 🔄 Processing batch 1087 (5,000 rows)...
# ✅ Batch 1087 complete. Progress: 96.8%
# 🔄 Processing batch 1088 (5,000 rows)...
# ✅ Batch 1088 complete. Progress: 96.9%
# 🔄 Processing batch 1089 (5,000 rows)...
# ✅ Batch 1089 complete. Progress: 96.9%
# 🔄 Processing batch 1090 (5,000 rows)...
# ✅ Batch 1090 complete. Progress: 97.0%
# 🔄 Processing batch 1091 (5,000 rows)...
# ✅ Batch 1091 complete. Progress: 97.1%
# 🔄 Processing batch 1092 (5,000 rows)...
# ✅ Batch 1092 complete. Progress: 97.2%
# 🔄 Processing batch 1093 (5,000 rows)...
# ✅ Batch 1093 complete. Progress: 97.3%
# 🔄 Processing batch 1094 (5,000 rows)...
# ✅ Batch 1094 complete. Progress: 97.4%
# 🔄 Processing batch 1095 (5,000 rows)...
# ✅ Batch 1095 complete. Progress: 97.5%
# 🔄 Processing batch 1096 (5,000 rows)...
# ✅ Batch 1096 complete. Progress: 97.6%
# 🔄 Processing batch 1097 (5,000 rows)...
# ✅ Batch 1097 complete. Progress: 97.7%
# 🔄 Processing batch 1098 (5,000 rows)...
# ✅ Batch 1098 complete. Progress: 97.7%
# 🔄 Processing batch 1099 (5,000 rows)...
# ✅ Batch 1099 complete. Progress: 97.8%
# 🔄 Processing batch 1100 (5,000 rows)...
# ✅ Batch 1100 complete. Progress: 97.9%
# 🔄 Processing batch 1101 (5,000 rows)...
# ✅ Batch 1101 complete. Progress: 98.0%
# 🔄 Processing batch 1102 (5,000 rows)...
# ✅ Batch 1102 complete. Progress: 98.1%
# 🔄 Processing batch 1103 (5,000 rows)...
# ✅ Batch 1103 complete. Progress: 98.2%
# 🔄 Processing batch 1104 (5,000 rows)...
# ✅ Batch 1104 complete. Progress: 98.3%
# 🔄 Processing batch 1105 (5,000 rows)...
# ✅ Batch 1105 complete. Progress: 98.4%
# 🔄 Processing batch 1106 (5,000 rows)...
# ✅ Batch 1106 complete. Progress: 98.5%
# 🔄 Processing batch 1107 (5,000 rows)...
# ✅ Batch 1107 complete. Progress: 98.5%
# 🔄 Processing batch 1108 (5,000 rows)...
# ✅ Batch 1108 complete. Progress: 98.6%
# 🔄 Processing batch 1109 (5,000 rows)...
# ✅ Batch 1109 complete. Progress: 98.7%
# 🔄 Processing batch 1110 (5,000 rows)...
# ✅ Batch 1110 complete. Progress: 98.8%
# 🔄 Processing batch 1111 (5,000 rows)...
# ✅ Batch 1111 complete. Progress: 98.9%
# 🔄 Processing batch 1112 (5,000 rows)...
# ✅ Batch 1112 complete. Progress: 99.0%
# 🔄 Processing batch 1113 (5,000 rows)...
# ✅ Batch 1113 complete. Progress: 99.1%
# 🔄 Processing batch 1114 (5,000 rows)...
# ✅ Batch 1114 complete. Progress: 99.2%
# 🔄 Processing batch 1115 (5,000 rows)...
# ✅ Batch 1115 complete. Progress: 99.3%
# 🔄 Processing batch 1116 (5,000 rows)...
# ✅ Batch 1116 complete. Progress: 99.3%
# 🔄 Processing batch 1117 (5,000 rows)...
# ✅ Batch 1117 complete. Progress: 99.4%
# 🔄 Processing batch 1118 (5,000 rows)...
# ✅ Batch 1118 complete. Progress: 99.5%
# 🔄 Processing batch 1119 (5,000 rows)...
# ✅ Batch 1119 complete. Progress: 99.6%
# 🔄 Processing batch 1120 (5,000 rows)...
# ✅ Batch 1120 complete. Progress: 99.7%
# 🔄 Processing batch 1121 (5,000 rows)...
# ✅ Batch 1121 complete. Progress: 99.8%
# 🔄 Processing batch 1122 (5,000 rows)...
# ✅ Batch 1122 complete. Progress: 99.9%
# 🔄 Processing batch 1123 (5,000 rows)...
# ✅ Batch 1123 complete. Progress: 100.0%
# 🔄 Processing batch 1124 (1,509 rows)...
# ✅ Batch 1124 complete. Progress: 100.0%
# 🎉 Processing complete! Results saved to: transformed_data/hash queryabril2024_with-temp-precip.csv
#
# 🎉 Success! Climate data extracted to: transformed_data/hash queryabril2024_with-temp-precip.csv
